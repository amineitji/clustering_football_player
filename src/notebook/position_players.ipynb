# %%
import requests
from bs4 import BeautifulSoup

class PlayerProfileScraper:
    def __init__(self, full_name):
        self.full_name = full_name
        self.full_name_for_url = full_name.replace(' ', '+')
        self.base_url = f"https://www.transfermarkt.com/schnellsuche/ergebnis/schnellsuche?query={self.full_name_for_url}"
        self.headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
        }

    def fetch_search_results(self):
        """Perform HTTP request to get search results."""
        response = requests.get(self.base_url, headers=self.headers)
        if response.status_code != 200:
            print(f"HTTP request error: {response.status_code}")
            return None
        return response.text

    def parse_first_table(self, html_content):
        """Parse HTML content to retrieve only the player's name, position, and age."""
        soup = BeautifulSoup(html_content, 'html.parser')
        table = soup.find('table', class_='items')
        
        if table is None:
            print("No table found.")
            return None

        # Extract the first row of the table
        first_row = table.find('tbody').find('tr')
        if first_row is None:
            print("No rows found in the table.")
            return None

        # Extract Name
        name_cell = first_row.find('td')
        print(name_cell)
        player_name = name_cell.find('a', title=True).text if name_cell.find('a', title=True) else "Unknown"

        # Extract Position (5th column)
        position = first_row.find_all('td')[4].text.strip()

        # Extract Age (7th column)
        age = first_row.find_all('td')[6].text.strip()

        # Print extracted data
        print("\nPlayer Information:")
        print(f"Name: {player_name}")
        print(f"Position: {position}")
        print(f"Age: {age}")
        
        return {
            "name": player_name,
            "position": position,
            "age": age
        }

    def save_player_profile(self):
        """Main method to fetch player profile and print player info."""
        html_content = self.fetch_search_results()
        if html_content:
            player_info = self.parse_first_table(html_content)
            if player_info:
                print(player_info)

if __name__ == "__main__":
    # Replace 'Player Name' with the name of the player you want to search for
    player_name = "Edinson Cavani"  
    scraper = PlayerProfileScraper(player_name)
    scraper.save_player_profile()
# Out:
# <td><table class="inline-table"><tr><td rowspan="2"><a href="#"><img alt="Edinson Cavani" class="bilderrahmen-fixed" src="https://img.a.transfermarkt.technology/portrait/small/48280-1619791055.jpg?lm=1" title="Edinson Cavani"/></a></td><td class="hauptlink"><a href="/edinson-cavani/profil/spieler/48280" title="Edinson Cavani">Edinson Cavani</a></td></tr><tr><td><a href="/club-atletico-boca-juniors/startseite/verein/189" title="CA Boca Juniors">CA Boca Juniors</a></td></tr></table></td>
#
# Player Information:
# Name: Edinson Cavani
# Position: CF
# Age: 37
# {'name': 'Edinson Cavani', 'position': 'CF', 'age': '37'}

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import asyncio

# Load the provided CSV file
file_path = '../../data/cleaned_scouting_report copy.csv'
scouting_report_df = pd.read_csv(file_path)

# Define the scraper class
class PlayerProfileScraper:
    def __init__(self, full_name):
        self.full_name = full_name
        self.full_name_for_url = full_name.replace(' ', '+')
        self.base_url = f"https://www.transfermarkt.com/schnellsuche/ergebnis/schnellsuche?query={self.full_name_for_url}"
        self.headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
        }

    def fetch_search_results(self):
        """Perform HTTP request to get search results."""
        try:
            response = requests.get(self.base_url, headers=self.headers)
            if response.status_code != 200:
                return None
            return response.text
        except requests.RequestException:
            return None

    def parse_first_table(self, html_content):
        """Parse HTML content to retrieve only the player's name, position, and age."""
        soup = BeautifulSoup(html_content, 'html.parser')
        tables = soup.find_all('table', class_='items')
        if not tables:
            return {"name": self.full_name, "position": "XX", "age": "XX"}
        
        table = tables[0]
        first_row = table.find('tbody').find('tr')
        if first_row is None:
            return {"name": self.full_name, "position": "XX", "age": "XX"}

        try:
            name_cell = first_row.find('td')
            player_name = name_cell.find('a', title=True).text if name_cell.find('a', title=True) else "Unknown"
            position = first_row.find_all('td')[4].text.strip() if len(first_row.find_all('td')) > 4 else "XX"
            age = first_row.find_all('td')[6].text.strip() if len(first_row.find_all('td')) > 6 else "XX"
        except IndexError:
            position, age = "XX", "XX"

        return {
            "name": player_name,
            "position": position,
            "age": age
        }

# Ensure 'Position' and 'Age' columns exist
if 'Age' not in scouting_report_df.columns:
    scouting_report_df['Age'] = None

# Define async function to enable await in retry
async def scrape_player_data(player_name, max_retries=3):
    scraper = PlayerProfileScraper(player_name)
    retries = 0
    player_info = {"position": "XX", "age": "XX"}
    
    while (player_info["position"] == "XX" or player_info["age"] == "XX") and retries < max_retries:
        html_content = scraper.fetch_search_results()
        if html_content:
            player_info = scraper.parse_first_table(html_content)
        retries += 1
        if player_info["position"] == "XX" or player_info["age"] == "XX":
            await asyncio.sleep(1)  # Await async sleep for retry

    return player_info

# Loop through each player and update Position and Age
async def update_scouting_report():
    for idx, row in scouting_report_df.iterrows():
        player_name = row['player_name']
        player_info = await scrape_player_data(player_name)
        scouting_report_df.at[idx, 'Position'] = player_info['position']
        scouting_report_df.at[idx, 'Age'] = player_info['age']
        
        # Log the result
        print(player_name, '-', player_info['position'], '-', player_info['age'])
        await asyncio.sleep(1)  # Respectful delay for new request

# Run the update function
await update_scouting_report()

# Save the updated dataframe
scouting_report_df[['player_name', 'Position', 'Age']].to_csv('../../data/updated_scouting_report.csv', index=False)
print("Updated scouting report saved to 'updated_scouting_report.csv'")
# Out:
# Denis Zakaria - DM - 27
# Eliesse Ben Seghir - LW - 19
# Vanderson - RB - 23
# Thilo Kehrer - CB - 28
# Takumi Minamino - LW - 29
# Lamine Camara - CM - 20
# Folarin Balogun - CF - 23
# Maghnes Akliouche - RW - 22
# Mohammed Salisu - CB - 25
# Wilfried Singo - CB - 23
# Breel Embolo - CF - 27
# Caio Henrique Oliveira Silva - LB - 27
# Aleksandr Golovin - AM - 28
# Ismail Jakobs - LB - 25
# Soungoutou Magassa - DM - 21
# Jordan Teze - RB - 25
# Christian Mawissa - CB - 19
# Kassoum Ouattara - LB - 20
# George Ilenikhena - CF - 18
# Krépin Diatta - RW - 25
# Guillermo Maripán - CB - 30
# Guillermo Maripán - CB - 30
# Willian Pacho - CB - 23
# Achraf Hakimi - RB - 25
# João Neves - DM - 20
# Warren Zaïre-Emery - CM - 18
# Bradley Barcola - LW - 22
# Marquinhos - CB - 30
# Lucas Beraldo - CB - 20
# Ousmane Dembélé - RW - 27
# Lee Kang-in - XX - XX
# Vitinha - CM - 24
# Marco Asensio - RW - 28
# Fabián Ruiz - CM - 28
# Nuno Mendes - LB - 22
# Randal Kolo Muani - CF - 25
# Désiré Doué - LW - 19
# Milan Škriniar - CB - 29
# Gonçalo Ramos - CF - 23
# Carlos Soler - CM - 27
# Robert Lewandowski - CF - 36
# Raphinha - LW - 27
# Jules Koundé - RB - 25
# Lamine Yamal - RW - 17
# Iñigo Martínez - CB - 33
# Pau Cubarsí - CB - 17
# Pedri - CM - 21
# Alejandro Balde - LB - 21
# Marc Casado - DM - 21
# Ferrán Torres - RW - 24
# Eric García - CB - 23
# Pablo Torre - AM - 21
# Dani Olmo - AM - 26
# Héctor Fort - RB - 18
# Fermin López - CM - 21
# Andreas Christensen - CB - 28
# Ansu Fati - LW - 22
# Frenkie de Jong - CM - 27
# Álex Valle - LB - 20
# Joshua Kimmich - DM - 29
# Dayot Upamecano - CB - 26
# Kim Min-jae - XX - XX
# Harry Kane - CF - 31
# Michael Olise - RW - 22
# Pavlovic - DM - 20
# Serge Gnabry - LW - 29
# Jamal Musiala - AM - 21
# Alphonso Davies - LB - 23
# Raphaël Guerreiro - LB - 30
# Kingsley Coman - LW - 28
# Sacha Boey - RB - 24
# Thomas Müller - SS - 35
# João Palhinha - DM - 29
# Konrad Laimer - CM - 27
# Mathys Tel - LW - 19
# Leroy Sané - RW - 28
# Eric Dier - CB - 30
# Leon Goretzka - CM - 29
# Virgil van Dijk - CB - 33
# Gravenberch - CM - 22
# Mohamed Salah - RW - 32
# Trent Alexander-Arnold - RB - 26
# Alexis Mac Allister - CM - 25
# Ibrahima Konaté - CB - 25
# Dominik Szoboszlai - CM - 24
# Andrew Robertson - LB - 30
# Diogo Jota - CF - 27
# Luis Díaz - LW - 27
# Cody Gakpo - LW - 25
# Curtis Jones - CM - 23
# Darwin Núñez - CF - 25
# Kostas Tsimikas - LB - 28
# Jarell Quansah - CB - 21
# Conor Bradley - RB - 21
# Federico Chiesa - RW - 27
# Harvey Elliott - CM - 21
# Wataru Endo - DM - 31
# Joe Gomez - CB - 27
# Kai Havertz - CF - 25
# Gabriel Magalhães - CB - 26
# William Saliba - CB - 23
# Thomas Partey - DM - 31
# Bukayo Saka - RW - 23
# Declan Rice - DM - 25
# Jurriën Timber - CB - 23
# Gabriel Martinelli - LW - 23
# Ben White - RB - 27
# Leandro Trossard - LW - 29
# Riccardo Calafiori - CB - 22
# Martin Ødegaard - AM - 25
# Jorginho - DM - 32
# Raheem Sterling - LW - 29
# Gabriel Jesus - CF - 27
# Oleksandr Zinchenko - LB - 27
# Mikel Merino - CM - 28
# Jakub Kiwior - CB - 24
# Takehiro Tomiyasu - RB - 25
# Eddie Nketiah - CF - 25
# Eddie Nketiah - CF - 25
# Erling Haaland - CF - 24
# Manuel Akanji - CB - 29
# Joško Gvardiol - LB - 22
# Rúben Dias - CB - 27
# Bernardo Silva - AM - 30
# Mateo Kovačić - CM - 30
# Rico Lewis - RB - 19
# İlkay Gündoğan - CM - 34
# Kevin De Bruyne - AM - 33
# Jeremy Doku - LW - 22
# Jack Grealish - LW - 29
# Sávio - RW - 20
# Kyle Walker - RB - 34
# Phil Foden - RW - 24
# John Stones - CB - 30
# Rodri - DM - 28
# Rodri Sánchez - RW - 24
# Matheus Nunes - CM - 26
# Nathan Aké - CB - 29
# James Mcatee - AM - 22
# Issa Kaboré - RB - 23
# Robin Koch - CB - 28
# Rasmus Kristensen - RB - 27
# Tuta - CB - 25
# Arthur Theate - CB - 24
# Hugo Larsson - CM - 20
# Omar Marmoush - CF - 25
# Ellyes Skhiri - DM - 29
# Hugo Ekitike - CF - 22
# Fares Chaïbi - AM - 21
# Mario Götze - AM - 32
# Ansgar Knauff - RW - 22
# Niels Nkounkou - LB - 23
# Igor Matanovic - CF - 21
# Junior Dina Ebimbe - RM - 23
# Mahmoud Dahoud - CM - 28
# Can Uzun - AM - 18
# Nathaniel Brown - LB - 21
# Valverde - CM - 26
# Éder Militão - CB - 26
# Antonio Rüdiger - CB - 31
# Vinicius Júnior - LW - 24
# Aurélien Tchouaméni - DM - 24
# Kylian Mbappé - CF - 25
# Dani Carvajal -  - XX
# Ferland Mendy - LB - 29
# Rodrygo - RW - 23
# Luka Modrić - CM - 39
# Jude Bellingham - AM - 21
# Arda Güler - RW - 19
# Fran Garcia - LB - 25
# Lucas Vázquez - RB - 33
# Brahim Díaz - AM - 25
# Camavinga - CM - 21
# Dani Ceballos - CM - 28
# Endrick - CF - 18
# Giovanni Di Lorenzo - RB - 31
# Amir Rrahmani - CB - 30
# Andre-Frank Zambo Anguissa - CM - 28
# Stanislav Lobotka - DM - 29
# Matteo Politano - RW - 31
# Khvicha Kvaratskhelia - LW - 23
# Alessandro Buongiorno - CB - 25
# Mathías Olivera - LB - 27
# Pasquale Mazzocchi - RB - 29
# Romelu Lukaku - CF - 31
# Scott McTominay - CM - 27
# Scott McTominay - CM - 27
# Giacomo Raspadori - SS - 24
# Leonardo Spinazzola - LB - 31
# Giovanni Simeone - CF - 29
# Juan Jesus - CB - 33
# David Neres - RW - 27
# Billy Gilmour - DM - 23
# Michael Folorunsho - CM - 26
# Walid Cheddira - CF - 26
# Walid Cheddira - CF - 26
# Cyril Ngonge - RW - 24
# Gianluca Gaetano - AM - 24
# Gianluca Gaetano - AM - 24
# Rafa Marín - CB - 22
# Alessio Zerbin - LW - 25
# Xavi Simons - AM - 21
# David Raum - LB - 26
# Benjamin Šeško - CF - 21
# Amadou Haidara - CM - 26
# Loïs Openda - CF - 24
# Castello Lukeba - CB - 21
# Lukas Klostermann - CB - 28
# Willi Orban - CB - 31
# Nicolas Seiwald - CM - 23
# Lutsharel Geertruida - RB - 24
# Kevin Kampl - CM - 34
# Antonio Nusa - LW - 19
# Benjamin Henrichs - RB - 27
# Arthur Vermeeren - DM - 19
# Arthur Vermeeren - DM - 19
# Christoph Baumgartner - AM - 25
# Yussuf Poulsen - CF - 30
# Mohamed Simakan - CB - 24
# André Silva - CF - 28
# Elif Elmas - AM - 25
# Levi Colwill - CB - 21
# Moisés Caicedo - DM - 22
# Wesley Fofana - CB - 23
# Cole Palmer - AM - 22
# Marc Cucurella - LB - 26
# Nicolas Jackson - CF - 23
# Enzo Fernández - CM - 23
# Noni Madueke - RW - 22
# Malo Gusto - RB - 21
# Jadon Sancho - LW - 24
# Pedro Neto - RW - 24
# Christopher Nkunku - AM - 26
# Tosin Adarabioyo - CB - 27
# Axel Disasi - CB - 26
# Mykhailo Mudryk - XX - XX
# João Félix - SS - 24
# Kiernan Dewsbury-Hall - CM - 26
# Benoît Badiashile - CB - 23
# Cesare Casadei - CM - 21
# Pau Torres - CB - 27
# Youri Tielemans - CM - 27
# Morgan Rogers - AM - 22
# Ezri Konsa - CB - 27
# Ollie Watkins - CF - 28
# Lucas Digne - LB - 31
# Amadou Onana - DM - 23
# John McGinn - CM - 30
# Leon Bailey - RW - 27
# Jacob Ramsey - AM - 23
# Matty Cash - RB - 27
# Diego Carlos - CB - 31
# Ross Barkley - CM - 30
# Jaden Philogene Bidace - XX - XX
# Jhon Durán - CF - 20
# Ian Maatsen - LB - 22
# Dušan Vlahović - CF - 24
# Andrea Cambiaso - LB - 24
# Gleison Bremer - CB - 27
# Kenan Yıldız - SS - 19
# Manuel Locatelli - DM - 26
# Federico Gatti - CB - 26
# Koopmeiners - AM - 26
# Pierre Kalulu - CB - 24
# Nicolò Fagioli - CM - 23
# Nicolás González - RW - 26
# Juan David Cabal - LB - 23
# Weston McKennie - CM - 26
# Khéphren Thuram - CM - 23
# Douglas Luiz - CM - 26
# Francisco Conceição - RW - 21
# Danilo - CB - 33
# Danilo - CB - 33
# Timothy Weah - RM - 24
# Michael Amir Murillo - RB - 28
# Pierre Højbjerg - XX - XX
# Mason Greenwood - RW - 23
# Luis Henrique - LW - 22
# Geoffrey Kondogbia - DM - 31
# Amine Harit - AM - 27
# Lilian Brassier - CB - 24
# Elye Wahi - CF - 21
# Leonardo Balerdi - CB - 25
# Quentin Merlin - LB - 22
# Neal Maupay - CF - 28
# Ismaël Koné - CM - 22
# Valentin Rongier - CM - 29
# Pol Lirola - RB - 27
# Ulisses Garcia - LB - 28
# Valentin Carboni - AM - 19
# Jon Rowe - LW - 21
# Adrien Rabiot - CM - 29
# Bamo Meïté - CB - 22
# Faris Pemi Moumbagna - CF - 24
# Antoine Griezmann - CF - 33
# Koke - CM - 32
# Robin Le Normand - CB - 27
# Marcos Llorente - RM - 29
# José María Giménez - CB - 29
# Julián Álvarez - CF - 24
# Conor Gallagher - CM - 24
# Alexander Sørloth - CF - 28
# Samuel Lino - LM - 24
# Reinildo Mandava - LB - 30
# César Azpilicueta - CB - 35
# Nahuel Molina - RB - 26
# Pablo Barrios - CM - 21
# Rodrigo De Paul - CM - 30
# Axel Witsel - CB - 35
# Rodrigo Riquelme - LW - 24
# Javi Galán - LB - 29
# Giuliano Simeone - CF - 21
# Clément Lenglet - CB - 29
# Ángel Correa - RW - 29
# Federico Dimarco - LB - 26
# Marcus Thuram - CF - 27
# Henrikh Mkhitaryan - CM - 35
# Francesco Acerbi - CB - 36
# Lautaro Martínez - CF - 27
# Alessandro Bastoni - CB - 25
# Matteo Darmian - RB - 34
# Hakan Çalhanoğlu - DM - 30
# Benjamin Pavard - CB - 28
# Nicolò Barella - CM - 27
# Davide Frattesi - CM - 25
# Yann Aurel Bisseck - CB - 23
# Mehdi Taremi - CF - 32
# Carlos Augusto - LB - 25
# Denzel Dumfries - RB - 28
# Kristjan Asllani - DM - 22
# Stefan de Vrij - CB - 32
# Piotr Zieliński - CM - 30
# Marko Arnautović - CF - 35
# Alessandro Fontanarosa - CB - 21
# Tiago Palacios - CB - 21
# Christian Günter - LB - 31
# Maximilian Eggestein - CM - 27
# Ritsu Doan - RW - 26
# Junior Adamu - CF - 23
# Philipp Lienhart - CB - 28
# Vincenzo Grifo - LW - 31
# Lukas Kübler - RB - 32
# Patrick Osterhage - CM - 24
# Matthias Ginter - CB - 30
# Eren Dinkçi - RW - 22
# Merlin Röhl - AM - 22
# Lucas Höler - CF - 30
# Florent Muslija - LW - 26
# Nicolas Höfler - DM - 34
# Noah Weißhaupt - LW - 23
# Roland Sallai - RW - 27
# Jordy Makengo - LB - 23
# Michael Gregoritsch - CF - 30
# Kiliann Sildillia - RB - 22
# Kiko Femenía - RB - 33
# Sergi Cardona - LB - 25
# Santi Comesaña - CM - 28
# Daniel Parejo - CM - 35
# Alex Baena - LW - 23
# Logan Costa - CB - 23
# Logan Costa - CB - 23
# Raúl Albiol - CB - 39
# Thierno Barry - CF - 22
# Eric Bailly - CB - 30
# Pape Gueye - DM - 25
# Ayoze Pérez - LW - 31
# Ilias Akhomach - RW - 20
# Arnaut Danjuma - LW - 27
# Arnaut Danjuma - LW - 27
# Gerard Moreno - CF - 32
# Ramón Terrats - DM - 24
# Pau Navarro - CB - 19
# Antonio Espigare - CB - 20
# Daniel Requena - CM - 20
# Bafodé Diakité - CB - 23
# Alexsandro Ribeiro - CB - 25
# Benjamin André - DM - 34
# Gabriel Gudmundsson - LB - 25
# Edon Zhegrova - RW - 25
# Angel Gomes - AM - 24
# Jonathan David - CF - 24
# Osame Sahraoui - LW - 23
# Tiago Santos - RB - 22
# Thomas Meunier - RB - 33
# Aïssa Mandi - CB - 33
# Rémy Cabella - AM - 34
# André Gomes - CM - 31
# Mohamed Lamine Bayo - CF - 26
# Hákon Arnar Haraldsson - LW - 21
# Ngal'Ayel Mukau - DM - 19
# Ismaily - LB - 34
# Mitchel Bakker - LB - 24
# Mitchel Bakker - LB - 24
# Jaka Bijol - CB - 25
# Kingsley Ehizibue - RB - 29
# Jesper Karlström - DM - 29
# Lorenzo Lucca - CF - 24
# Florian Thauvin - RW - 31
# Brenner - CF - 24
# Christian Kabasele - CB - 33
# Hassane Kamara - LB - 30
# Sandi Lovrić - CM - 26
# Lautaro Gianetti - XX - XX
# Jordan Zemura - LB - 24
# Martín Payero - CM - 26
# Jurgen Ekkelenkamp - AM - 24
# Oier Zarraga - CM - 25
# Souleymane Touré - Attack - 22
# Thomas Kristensen - CB - 22
# Nehuén Pérez - CB - 24
# Arthur Atta - DM - 21
# Festy Ebosele - RB - 22
# Christian Pulisic - RW - 26
# Fikayo Tomori - CB - 26
# Tijjani Reijnders - CM - 26
# Rafael Leão - LW - 25
# Theo Hernández - LB - 27
# Emerson - LB - 30
# Youssouf Fofana - DM - 25
# Ruben Loftus-Cheek - CM - 28
# Matteo Gabbia - CB - 25
# Tammy Abraham - CF - 27
# Tammy Abraham - CF - 27
# Álvaro Morata - CF - 32
# Strahinja Pavlović - CB - 23
# Noah Okafor - LW - 24
# Samuel Chukwueze - RW - 25
# Davide Calabria - RB - 27
# Yunus Musah - CM - 21
# Alexis Saelemaekers - RW - 25
# Alexis Saelemaekers - RW - 25
# Filippo Terracciano - RB - 21
# Malick Thiaw - CB - 23
# Luka Jović - CF - 26
# Ismaël Bennacer - DM - 26
# Jonathan Tah - CB - 28
# Granit Xhaka - DM - 32
# Grimaldo - LB - 29
# Florian Wirtz - AM - 21
# Edmond Tapsoba - CB - 25
# Victor Boniface - CF - 23
# Piero Hincapié - CB - 22
# Jeremie Frimpong - RM - 23
# Robert Andrich - DM - 30
# Martin Terrier - LW - 27
# Aleix García - CM - 27
# Jonas Hofmann - AM - 32
# Amine Adli - LW - 24
# Patrik Schick - CF - 28
# Nathan Tella - RM - 25
# Exequiel Palacios - CM - 26
# Nordi Mukiele - RB - 26
# Jeanuël Belocian - CB - 19
# Odilon Kossounou - CB - 23
# Odilon Kossounou - CB - 23
# Emmanuel Agbadou - CB - 27
# Marshall Munetsi - CM - 28
# Junya Ito - RW - 31
# Valentin Atangana Edoa - CM - 19
# Oumar Diakité - CF - 20
# Keito Nakamura - LW - 24
# Yaya Kader Fofana - CM - 20
# Aurélio Buta - RB - 27
# Cédric Kipré - CB - 27
# Sergio Akieme - LB - 26
# Joseph Okumu - CB - 27
# Teddy Teuma - CM - 31
# Amadou Koné - CF - 32
# Amine Salama - CF - 24
# Reda Khadra - AM - 23
# Martin Adeline - CM - 20
# Mohammed Daramy - LW - 22
# Thibault De Smet - LB - 26
# Gabriel Moscardo - DM - 19
# Danilho Doekhi - CB - 26
# Rani Khedira - DM - 30
# Diogo Leite - CB - 25
# Kevin Vogt - CB - 33
# Benedict Hollerbach - CF - 23
# Tom Rothe - LB - 20
# András Schäfer - CM - 25
# Janik Haberer - CM - 30
# Jordan Pefok - CF - 28
# Jeong Woo-yeong - XX - XX
# Yorbe Vertessen - CF - 23
# Christopher Trimmel - RB - 37
# Lucas Tousart - DM - 27
# Tim Skarke - RW - 28
# László Bénes - CM - 27
# Robin Gosens - LB - 30
# Robin Gosens - LB - 30
# Aljoscha Kemlein - DM - 20
# Jérôme Roussillon - LB - 31
# Robert Skov - LM - 28
# Jonas Föhrenbach - LB - 28
# Benedikt Gimber - CB - 27
# Patrick Mainka - CB - 29
# Omar Traoré - RB - 26
# Paul Wanner - AM - 18
# Jan Schöppner - CM - 25
# Marvin Pieringer - CF - 25
# Lennard Maloney - DM - 25
# Marnon Busch - RB - 29
# Adrian Beck - AM - 27
# Mikkel Kaufmann - CF - 23
# Niklas Dorsch - DM - 26
# Niklas Dorsch - XX - XX
# Mathias Honsak - LW - 27
# Sirlord Conteh - RW - 28
# Norman Theuerkauf - DM - 37
# Iñaki Williams - RW - 30
# Daniel Vivian - CB - 25
# Oihan Sancet - AM - 24
# Álex Berenguer - LW - 29
# Gorka Guruzeta - CF - 28
# Yuri Berchiche - LB - 34
# Aitor Paredes - CB - 24
# Beñat Prados - CM - 23
# Nico Williams - LW - 22
# Óscar de Marcos - RB - 35
# Mikel Jauregizar - CM - 20
# Yeray Álvarez - CB - 29
# Mikel Vesga - DM - 31
# Iñigo Lekue - RB - 31
# Iñigo Ruiz de Galarreta - CM - 31
# Unai Gómez - AM - 21
# Ander Herrera - CM - 35
# Álvaro djaló - LW - 25
# Andoni Gorosabel - RB - 28
# Unai Núñez - CB - 27
# Javi Martón - XX - XX
# Nicolás Serrano - LW - 21
# Dan Burn - CB - 32
# Bruno Guimarães - DM - 26
# Anthony Gordon - LW - 23
# Joelinton - CM - 28
# Jacob Murphy - RW - 29
# Alexander Isak - CF - 25
# Fabian Schär - CB - 32
# Lewis Hall - LB - 20
# Harvey Barnes - LW - 26
# Valentino Livramento - RB - 21
# Sean Longstaff - CM - 27
# Kieran Trippier - RB - 34
# Lloyd Kelly - CB - 26
# Emil Krafth - RB - 30
# Joe Willock - CM - 25
# Miguel Almirón - RW - 30
# William Osula - CF - 21
# Cristian Romero - CB - 26
# Pedro Porro - RB - 25
# Destiny Udogie - LB - 21
# James Maddison - AM - 27
# Micky van de Ven - CB - 23
# Dejan Kulusevski - AM - 24
# Brennan Johnson - RW - 23
# Son Heung-min - XX - XX
# Dominic Solanke - CF - 27
# Rodrigo Bentancur - DM - 27
# Pape Matar Sarr - CM - 22
# Timo Werner - LW - 28
# Yves Bissouma - DM - 28
# Wilson Odobert - RW - 19
# Radu Drăgușin - CB - 22
# Djed Spence - RB - 24
# Archie Gray - CM - 18
# Richarlison - CF - 27
# Ben Davies - CB - 31
# Alfie Devine - AM - 20
# Facundo Medina - CB - 25
# Adrien Thomasson - AM - 30
# Andy Diouf - CM - 21
# Jonathan Gradit - CB - 31
# Abdukodir Khusanov - CB - 20
# Florian Sotoca - CF - 34
# Jhoanner Chávez - LB - 22
# Wesley Saïd - CF - 29
# Przemysław Frankowski - RM - 29
# Ruben Aguilar - RB - 31
# Angelo Fulgini - AM - 28
# Anass Zaroury - AM - 23
# Rémy Labeau Lascary - CF - 21
# Deiver Machado - LB - 31
# M'Bala Nzola - CF - 28
# Kevin Danso - CB - 26
# David Costa - AM - 23
# Nampalys Mendy - DM - 32
# Martin Satriano - CF - 23
# Neil El Aynaoui - CM - 23
# Massadio Haïdara - LB - 31
# Massadio Haïdara - LB - 31
# Ardian Ismajli - CB - 28
# Mattia Viti - CB - 22
# Emmanuel Gyasi - LW - 30
# Giuseppe Pezzella - LB - 26
# Liam Henderson - CM - 28
# Lorenzo Colombo - CF - 22
# Sebastiano Esposito - SS - 22
# Saba Goglichidze - CB - 20
# Alberto Grassi - DM - 29
# Jacopo Fazzini - CM - 21
# Youssef Maleh - CM - 26
# Sebastian Walukiewicz - CB - 24
# Sebastian Walukiewicz - CB - 24
# Liberato Cacace - LB - 24
# Pietro Pellegri - CF - 23
# Pietro Pellegri - CF - 23
# Francesco Caputo - CF - 37
# Petar Stojanović - RB - 29
# Junior Sambia - RB - 28
# Mattéo Guendouzi - CM - 25
# Mattia Zaccagni - LW - 29
# Manuel Lazzari - RM - 30
# Alessio Romagnoli - CB - 29
# Valentín Castellanos - CF - 26
# Nicolò Rovella - DM - 22
# Nuno Tavares - LB - 24
# Boulaye Dia - CF - 27
# Mario Gila - CB - 24
# Gustav Isaksen - RW - 23
# Tijjani Noslin - RW - 25
# Adam Marušić - RB - 32
# Patric - DM - 48
# Nicolò Casale - CB - 26
# Nicolò Casale - CB - 26
# Matías Vecino - CM - 33
# Loum Tchaouna - RW - 21
# Gaetano Castrovilli - CM - 27
# Pedro - RW - 37
# Luca Pellegrini - LB - 25
# Elseid Hysaj - RB - 30
# Danilo Cataldi - DM - 30
# Danilo Cataldi - DM - 30
# Samuel Gigot - CB - 31
# Waldemar Anton - CB - 28
# Julian Ryerson - RB - 26
# Julian Brandt - AM - 28
# Pascal Groß - CM - 33
# Nico Schlotterbeck - CB - 24
# Emre Can - DM - 30
# Serhou Guirassy - CF - 28
# Niklas Süle - CB - 29
# Karim Adeyemi - LW - 22
# Marcel Sabitzer - CM - 30
# Jamie Gittens - LW - 20
# Yan Couto - RB - 22
# Maximilian Beier - CF - 22
# Donyell Malen - RW - 25
# Felix Nmecha - CM - 24
# Ramy Bensebaini - LB - 29
# Gio Reyna - AM - 21
# Sébastien Haller - CF - 30
# Sébastien Haller - CF - 30
# Lucas Torró - DM - 30
# Aimar Oroz - AM - 22
# Catena - CB - 30
# Jesús Areso - RB - 25
# Abel - LB - 43
# Ante Budimir - CF - 33
# Bryan Zaragoza - LW - 23
# Rubén García - RW - 31
# Enzo Boyomo - CB - 23
# Enzo Boyomo - CB - 23
# Jon Moncayola - CM - 26
# Jorge Herrando - CB - 23
# Moi Gómez - LW - 30
# Pablo Ibáñez - CB - 43
# Raúl - CB - 39
# Juan Cruz Armada - XX - XX
# Rubén Peña - RB - 33
# Nacho Vidal - RB - 29
# Iker Muñoz - DM - 22
# Iker Benito - RW - 22
# José Arnaiz - LW - 29
# Javi Martínez - DM - 36
# Unai García - CB - 32
# Angelo Stiller - DM - 23
# Julian Chabot - CB - 26
# Jamie Leweling - RW - 23
# Atakan Karazor - DM - 28
# Maximilian Mittelstädt - LB - 27
# Enzo Millot - AM - 22
# Deniz Undav - CF - 28
# Ermedin Demirović - CF - 26
# Josha Vagnoman - RB - 23
# Anthony Rouault - CB - 23
# Fabian Rieder - AM - 22
# Chris Führich - LW - 26
# Pascal Stenzel - RB - 28
# El Bilal Touré - CF - 23
# Nick Woltemade - SS - 22
# Dan-Axel Zagadou - CB - 25
# Ramon Hendriks - CB - 23
# Silas Katompa - RW - 26
# Yannik Keitel - DM - 24
# Calvin Bassey - CB - 24
# Antonee Robinson - LB - 27
# Kenny Tete - RB - 29
# Alex Iwobi - LW - 28
# Adama Traoré - RW - 28
# Saša Lukić - CM - 28
# Andreas Pereira - AM - 28
# Emile Smith Rowe - AM - 24
# Joachim Andersen - CB - 28
# Joachim Andersen - CB - 28
# Raúl Jiménez - CF - 33
# Rodrigo Muniz - CF - 23
# Issa Diop - CB - 27
# Sander Berge - DM - 26
# Tom Cairney - CM - 33
# Harrison Reed - CM - 29
# Harry Wilson - RW - 27
# Timothy Castagne - RB - 28
# Jay Stansfield - CF - 21
# Jorge Cuenca - CB - 24
# Samuele Ricci - DM - 23
# Duván Zapata - CF - 33
# Valentino Lazaro - LM - 28
# Adam Masina - CB - 30
# Saúl Coco - CB - 25
# Ivan Ilić - CM - 23
# Karol Linetty - CM - 29
# Mërgim Vojvoda - RB - 29
# Che Adams - CF - 28
# Borna Sosa - LM - 26
# Adrien Tameze - DM - 30
# Antonio Sanabria - CF - 28
# Marcus Pedersen - RM - 24
# Gvidas Gineitis - CM - 20
# Raoul Bellanova - RM - 24
# Raoul Bellanova - RM - 24
# Nikola Vlašić - AM - 27
# Antonio Raillo - CB - 33
# Samu Costa - DM - 23
# Johan Mojica - LB - 32
# Sergi Darder - CM - 30
# Dani Rodríguez - AM - 36
# Martin Valjent - CB - 28
# Pablo Maffeo - RB - 27
# Vedat Muriqi - CF - 30
# Omar Mascarell - DM - 31
# Cyle Larin - CF - 29
# Antonio Sánchez - CM - 27
# Manu Morlanes - CM - 25
# Roberto Navarro - RB - 37
# Takuma Asano - RW - 29
# Copete - CF - 31
# Toni Lato - LB - 26
# Abdón Prats - CF - 31
# Valery Fernández - RW - 24
# Chiquinho - AM - 29
# Chiquinho - AM - 29
# Obite N'Dicka - XX - XX
# Angeliño - LB - 27
# Artem Dovbyk - CF - 27
# Gianluca Mancini - CB - 28
# Bryan Cristante - DM - 29
# Lorenzo Pellegrini - AM - 28
# Zeki Çelik - RB - 27
# Matìas Soulé - RW - 21
# Stephan El Shaarawy - LW - 32
# Paulo Dybala - SS - 30
# Manu Koné - CM - 23
# Nicola Zalewski - LM - 22
# Leandro Paredes - DM - 30
# Enzo Le Fée - CM - 24
# Tommaso Baldanzi - AM - 21
# Mario Hermoso - CB - 29
# Eldor Shomurodov - CF - 29
# Edoardo Bove - CM - 22
# Edoardo Bove - CM - 22
# Mats Hummels - CB - 35
# Pedro Chirivella - DM - 27
# Moses Simon - LW - 29
# Matthis Abline - CF - 21
# Douglas - CM - 26
# Kelvin Amian - RB - 26
# Jean-Charles Castelletto - CB - 29
# Nathan Zeze - CB - 19
# Johann Lepenant - DM - 22
# Sorba Thomas - RW - 25
# Nicolas Pallois - CB - 37
# Jean-Kevin Duverne - CB - 27
# Tino Kadewere - CF - 28
# Marcus Coco - RW - 28
# Nicolas Cozza - LB - 25
# Nicolas Cozza - LB - 25
# Jean-Philippe Gbamin - DM - 29
# Mostafa Mohamed - CF - 26
# Florent Mollet - AM - 32
# Guela Doué - RB - 22
# Dilane Bakwa - RW - 22
# Saidou Sow - CB - 22
# Emanuel Emegha - CF - 21
# Ismaël Doukouré - DM - 21
# Habib Diarra - AM - 20
# Andrey Santos - CM - 20
# Diego Moreira - LW - 20
# Abakar Sylla - CB - 21
# Caleb Wiley - LB - 19
# Mamadou Sarr - CB - 19
# Junior Mwanga - DM - 21
# Félix Lemaréchal - AM - 21
# Marvin Senaya - RB - 23
# Nordine Kandil - LW - 23
# Kaoru Mitoma - LW - 27
# Lewis Dunk - CB - 32
# Jack Hinshelwood - RB - 19
# Danny Welbeck - CF - 33
# Joël Veltman - RB - 32
# Jan Paul van Hecke - CB - 24
# Carlos Baleba - DM - 20
# Yankuba Minteh - RW - 20
# Georginio Rutter - CF - 22
# João Pedro - RB - 30
# James Milner - CM - 38
# Pervis Estupiñán - LB - 26
# Mats Wieffer - DM - 24
# Ferdi Kadioglu - LB - 25
# Adam Webster - CB - 29
# Yasin Ayari - CM - 21
# Simon Adingra - RW - 22
# Igor - CB - 27
# Julio Enciso - AM - 20
# Evan Ferguson - CF - 20
# Jeremy Sarmiento - LW - 22
# Brajan Gruda - RW - 20
# Valentín Barco - LB - 20
# Valentín Barco - LB - 20
# Tariq Lamptey - RB - 24
# Jakub Moder - CM - 25
# Murillo - CB - 22
# Ola Aina - RB - 28
# Chris Wood - CF - 32
# Nikola Milenković - CB - 27
# Morgan Gibbs-White - AM - 24
# Elliot Anderson - CM - 21
# Callum Hudson-Odoi - LW - 23
# Anthony Elanga - RW - 22
# Álex Moreno - LB - 31
# James Ward-Prowse - CM - 29
# James Ward-Prowse - CM - 29
# Ryan Yates - CM - 26
# Neco Williams - RB - 23
# Ibrahim Sangaré - DM - 26
# Nicolás Domínguez - CM - 26
# Willy Boly - CB - 33
# Taiwo Awoniyi - CF - 27
# Jota Silva - LW - 25
# Ramón Sosa - LW - 25
# Morato - CB - 23
# Harry Toffolo - LB - 29
# Andrew Omobamidele - CB - 22
# Diego Llorente - CB - 31
# Marc Roca - DM - 27
# Abde Ezzalzouli - LW - 22
# Natan - CB - 39
# Pablo Fornals - AM - 28
# Romain Perraud - LB - 27
# Giovani Lo Celso - CM - 28
# Héctor Bellerín - RB - 29
# Aitor Ruibal - RW - 28
# Ricardo Rodríguez - LB - 32
# Youssouf Sabaly - RB - 31
# William Carvalho - DM - 32
# Sergi Altimira - CM - 23
# Vitor Roque - CB - 48
# Johnny Cardoso - DM - 23
# Ezequiel Ávila - CF - 30
# Nabil Fekir - AM - 31
# Assane Diao - DM - 47
# Juanmi - LW - 31
# Iker Losada - SS - 23
# Florian Lejeune - CB - 33
# Abdul Mumin - CB - 26
# Óscar Valentín - CM - 30
# Andrei Ratiu - RB - 26
# Jorge de Frutos - RW - 27
# Adri Embarba - XX - XX
# Sergio Camello - CF - 23
# Unai López - CM - 29
# Isaac Palazón Camacho - RW - 29
# Iván Balliu - RB - 32
# Álvaro García - LW - 32
# Alfonso Espino - LB - 32
# Pep Chavarría - LB - 26
# Pathé Ciss - CM - 30
# Randy Nteka - AM - 26
# Óscar Trejo - AM - 36
# Gerard Gumbau - DM - 29
# James Rodríguez - AM - 33
# Pedro Díaz - CM - 26
# Sergi Guardiola - CF - 33
# Aridane Hernández - CB - 35
# Raúl de Tomás - CF - 30
# Óscar Mingueza - RB - 25
# Hugo Álvarez - LW - 21
# Iago Aspas - CF - 37
# Carl Starfelt - CB - 29
# Fran Beltrán - CM - 25
# Borja Iglesias - CF - 31
# Javi Rodríguez - CB - 21
# Damián Rodríguez - DM - 21
# Jailson Siqueira -  - XX
# Williot Swedberg - LW - 20
# Carlos Dominguez - CB - 23
# Ilaix Moriba - CM - 21
# Javier Manquillo - RB - 30
# Marcos Alonso - LB - 33
# Anastasios Douvikas - CF - 25
# Hugo Sotelo - CM - 20
# Jonathan Bamba - LW - 28
# Sergio Carreira - RB - 24
# Marten de Roon - DM - 33
# Éderson - GK - 31
# Berat Djimsiti - CB - 31
# Mateo Retegui - CF - 25
# Charles De Ketelaere - AM - 23
# Mario Pašalić - CM - 29
# Matteo Ruggeri - LM - 22
# Davide Zappacosta - RM - 32
# Marco Brescianini - CM - 24
# Sead Kolašinac - CB - 31
# Isak Hien - CB - 25
# Ademola Lookman - SS - 27
# Lazar Samardzic - CM - 22
# Nicolò Zaniolo - AM - 25
# Rafael Tolói - CB - 34
# Ben Godfrey - CB - 26
# Ibrahim Sulemana - DM - 21
# Nathan Collins - CB - 23
# Ethan Pinnock - CB - 31
# Bryan Mbeumo - RW - 25
# Vitaly Janelt - DM - 26
# Kristoffer Ajer - CB - 26
# Mikkel Damsgaard - LW - 24
# Keane Lewis-Potter - LW - 23
# Christian Nørgaard - DM - 30
# Sepp van den Berg - CB - 22
# Kevin Schade - LW - 22
# Yoane Wissa - CF - 28
# Mathias Jensen - CM - 28
# Mads Roerslev - RB - 25
# Fabio Carvalho - AM - 22
# Yehor Yarmoliuk - AM - 20
# Frank Onyeka - CM - 26
# Frank Onyeka - CM - 26
# Ben Mee - CB - 35
# Evann Guessand - CF - 23
# Dante - CB - 41
# Jonathan Clauss - RB - 32
# Tanguy Ndombele - CM - 27
# Mohamed Ali Cho - RW - 20
# Hicham Boudaoui - CM - 25
# Pablo Rosario - DM - 27
# Moïse Bombito - CB - 24
# Youssouf Ndayishimiye - DM - 26
# Melvin Bard - LB - 23
# Antoine Mendy - RB - 20
# Jeremie Boga - LW - 27
# Badredine Bouanani - RW - 19
# Ali Abdi - LB - 30
# Youssoufa Moukoko - CF - 19
# Gaëtan Laborde - CF - 30
# Jordan Lotomba - RB - 26
# Tom Louchet - RM - 21
# Jonathan Burkardt - CF - 24
# Phillipp Mwene - LB - 30
# Dominik Kohr - DM - 30
# Kaishu Sano - DM - 23
# Anthony Caci - LB - 27
# Lee Jae-sung - XX - XX
# Nadiem Amiri - CM - 28
# Moritz Jenz - CB - 25
# Andreas Hanche-Olsen - CB - 27
# Hong Hyunseok - XX - XX
# Maxim Leitsch - CB - 26
# Armindo Sieb - SS - 21
# Silvan Widmer - RB - 31
# Karim Onisiwo - CF - 32
# Aymen Barkok - AM - 26
# Paul Nebel - AM - 22
# Danny da Costa - RB - 31
# Marco Richter - AM - 26
# Mitchell Weiser - RB - 30
# Romano Schmid - AM - 24
# Jens Stage - CM - 27
# Felix Agu - RB - 25
# Marvin Ducksch - CF - 30
# Anthony Jung - CB - 32
# Senne Lynen - DM - 25
# Niklas Stark - CB - 29
# Marco Friedl - CB - 26
# Derrick Köhn - LB - 25
# Julián Malatini - CB - 23
# Justin Njinmah - RW - 23
# Keke Maximilian Topp - CF - 20
# Skelly Alvero - CM - 22
# Miloš Veljković - CB - 29
# Leonardo Bittencourt - CM - 30
# Olivier Deman - LM - 24
# Oliver Burke - RW - 27
# Jackson Tchatchoua - RB - 23
# Darko Lazović - LM - 34
# Reda Belahyane - DM - 20
# Diego Coppola - CB - 20
# Casper Tengstedt - CF - 24
# Paweł Dawidowicz - CB - 29
# Ondrej Duda - CM - 29
# Grigoris Kastanos - AM - 26
# Giangiacomo Magnani - CB - 29
# Tomáš Suslov - AM - 22
# Daniel Bandeira -  - XX
# Flavius Daniliuc - CB - 23
# Abdou Harroui - CM - 26
# Domagoj Bradarić - LB - 24
# Daniele Ghilardi - CB - 21
# Suat Serdar - CM - 27
# Faride Alidou - LW - 23
# Davide Faraoni - RB - 33
# Yllan Okou - CB - 21
# Stefan Mitrović - LW - 22
# Abdel Abqar - CB - 25
# Carlos Vicente - RW - 25
# Nahuel Tenaglia - RB - 28
# Manu Sánchez - LB - 24
# Antonio Blanco - DM - 24
# Stoichkov - LW - 58
# Ander Guevara - CM - 27
# Aleksandar Sedlar - CB - 32
# Kiké - CB - 22
# Moussa Diarra - CB - 23
# Jon Guridi - CM - 29
# Carlos Benavídez - licensed - XX
# Santiago Mouriño - CB - 22
# Hugo Novoa - RB - 21
# Abderrahman Rebbach - LW - 26
# Carlos Martín - AM - 42
# Asier Villalibre - CF - 27
# Luka Romero - RW - 19
# Luis Rioja - LW - 31
# Luis Rioja - LW - 31
# Joaquín Panichelli - CF - 22
# Sebastiaan Bornauw - CB - 25
# Maximilian Arnold - CM - 30
# Jakub Kamiński - LW - 22
# Tiago Tomás - CF - 23
# Kilian Fischer - RB - 24
# Cedric Zesiger - CB - 26
# Ridle Baku - RB - 26
# Mattias Svanberg - CM - 25
# Patrick Wimmer - RW - 23
# Mohamed Amoura - CF - 24
# Konstantinos Koulierakis - CB - 20
# Jonas Wind - CF - 25
# Lovro Majer - AM - 26
# Salih Özcan - DM - 26
# Aster Vranckx - CM - 22
# Denis Vavro - CB - 28
# Yannick Gerhardt - CM - 30
# Kevin Behrens - CF - 33
# Joakim Mæhle - XX - XX
# Dodô - RB - 25
# Moise Kean - CF - 24
# Pietro Comuzzo - CB - 19
# Andrea Colpani - AM - 25
# Luca Ranieri - CB - 25
# Cristiano Biraghi - LB - 32
# Rolando Mandragora - DM - 27
# Christian Kouamé - LW - 26
# Lucas Martínez Quarta - CB - 28
# Albert Guðmundsson - SS - 27
# Sofyan Amrabat - DM - 28
# Yacine Adli - DM - 24
# Amir Richardson - CM - 22
# Fabiano Parisi - LB - 23
# Marin Pongračić - CB - 27
# Lucas Beltrán - CF - 23
# Antonín Barák - AM - 29
# Jonathan Ikone - RW - 26
# Riccardo Sottil - LW - 25
# Michael Kayode - RB - 20
# Alessandro Bianco - CM - 22
# Alessandro Bianco - CM - 22
# Matias Moreno - CB - 21
# Remo Freuler - CM - 32
# Sam Beukema - CB - 25
# Santiago Castro - CF - 20
# Riccardo Orsolini - RW - 27
# Stefan Posch - RB - 27
# Dan Ndoye - RW - 24
# Charalambos Lykogiannis - XX - XX
# Michel Aebischer - CM - 27
# Nikola Moro - DM - 26
# Jhon Lucumí - CB - 26
# Giovanni Fabbian - AM - 21
# Martin Erlic - CB - 26
# Juan Miranda - LB - 24
# Jens Odgaard - CF - 25
# Kacper Urbanski - CM - 20
# Thijs Dallinga - CF - 24
# Emil Holm - RB - 24
# Samuel Iling-Junior - LW - 21
# Nicolò Cambiaghi - SS - 23
# Benjamín Domínguez - LW - 21
# Diogo Dalot - RB - 25
# Kobbie Mainoo - CM - 19
# Bruno Fernandes - AM - 30
# Noussair Mazraoui - RB - 26
# Lisandro Martínez - CB - 26
# Marcus Rashford - LW - 27
# Alejandro Garnacho - LW - 20
# Matthijs de Ligt - CB - 25
# Joshua Zirkzee - CF - 23
# Amad Diallo - RW - 22
# Casemiro - DM - 32
# Christian Eriksen - CM - 32
# Harry Maguire - CB - 31
# Jonny Evans - CB - 36
# Manuel Ugarte Ribeiro - DM - 23
# Rasmus Højlund - CF - 21
# Victor Lindelöf - CB - 30
# Antony - RW - 24
# Duje Ćaleta-Car - CB - 28
# Clinton Mata - RB - 31
# Abner - LB - 24
# Maxence Caqueret - CM - 24
# Ainsley Maitland-Niles - RB - 27
# Moussa Niakhate - CB - 28
# Alexandre Lacazette - CF - 33
# Nemanja Matić - DM - 36
# Saïd Benrahma - LW - 29
# Corentin Tolisso - CM - 30
# Georges Mikautadze - CF - 24
# Jordan Veretout - CM - 31
# Malick Fofana - LW - 19
# Gift Orban - CF - 22
# Nicolás Tagliafico - LB - 32
# Ernest Nuamah - RW - 20
# Rayan Cherki - AM - 21
# Thiago Almada - AM - 23
# Tanner Tessmann - DM - 23
# Sael Kumbedi - RB - 19
# Orel Mangala - CM - 26
# Orel Mangala - CM - 26
# Mama Samba Baldé - CF - 28
# Mama Samba Baldé - CF - 28
# Adryelson - CB - 26
# Warmed Omari - CB - 24
# Warmed Omari - CB - 24
# Jeffrey Gouweleeuw - CB - 33
# Dimitris Giannoulis - LB - 29
# Elvis Rexhbeçaj - CM - 26
# Keven Schlotterbeck - CB - 27
# Kristijan Jakić - DM - 27
# Maximilian Bauer - CB - 24
# Phillip Tietz - CF - 27
# Samuel Essende - CF - 26
# Marius Wolf - RB - 29
# Ruben Vargas - LW - 26
# Arne Maier - CM - 25
# Mads Pedersen - LB - 28
# Tim Breithaupt - DM - 22
# Steve Mounié - CF - 30
# Fredrik Jensen - AM - 27
# Arne Engels - CM - 21
# Chrislain Matsima - CB - 22
# Yusuf Kabadayı - LW - 20
# Alexis Claude-Maurice - AM - 26
# Max Kilman - CB - 27
# Jarrod Bowen - RW - 27
# Mohammed Kudus - AM - 24
# Guido Rodríguez - DM - 30
# Emerson Palmieri - LB - 30
# Lucas Paquetá - AM - 27
# Michail Antonio - CF - 34
# Konstantinos Mavropanos - CB - 26
# Aaron Wan-Bissaka - RB - 26
# Tomáš Souček - DM - 29
# Edson Álvarez - DM - 27
# Vladimír Coufal - RB - 32
# Jean-Clair Todibo - CB - 24
# Crysencio Summerville - LW - 23
# Niclas Füllkrug - CF - 31
# Danny Ings - CF - 32
# Aaron Cresswell - LB - 34
# Luis Guilherme - RW - 18
# Illia Zabarnyi - CB - 22
# Lewis Cook - CM - 27
# Antoine Semenyo - RW - 24
# Marcus Tavernier - LM - 25
# Milos Kerkez - LB - 20
# Ryan Christie - CM - 29
# Evanilson - CF - 25
# Marcos Senesi - CB - 27
# Justin Kluivert - LW - 25
# Adam Smith - RB - 33
# Julian Araujo - RB - 23
# Dango Ouattara - LW - 22
# Dean Huijsen - CB - 19
# Alex Scott - CM - 21
# Luis Sinisterra - LW - 25
# Enes Ünal - CF - 27
# Philip Billing - CM - 28
# David Brooks - RW - 27
# Max Aarons - RB - 24
# Jaidon Anthony - LW - 24
# James Hill - CB - 22
# Hamed Junior Traorè - AM - 24
# Hamed Junior Traorè - AM - 24
# Alberto Moreno - LB - 32
# Gabriel Strefezza - RW - 27
# Patrick Cutrone - CF - 26
# Alberto Dossena - CB - 26
# Máximo Perrone - DM - 21
# Marc-Oliver Kempf - XX - XX
# Nicolás Paz - AM - 20
# Sergi Roberto - CM - 32
# Alieu Fadera - LW - 22
# Ignace Van Der Brempt - RB - 22
# Alessio Iovine - RM - 33
# Andrea Belotti - CF - 30
# Lucas Da Cunha - LW - 23
# Federico Barba - CB - 31
# Luca Mazzitelli - CM - 28
# Matthias Braunöder - CM - 22
# Edoardo Goldaniga - CB - 30
# Marco Sala - LB - 25
# Daniele Baselli - CM - 32
# Yannik Engelhardt - DM - 23
# Alberto Cerri - CF - 28
# Alessandro Gabrielloni - CF - 30
# Simone Verdi - AM - 32
# Oliver Abildgaard - DM - 28
# Tommaso Cassandro - RB - 24
# Carmona - RB - 27
# Dodi Lukebakio - RW - 27
# Loïc Bade - CB - 24
# Nemanja Gudelj - DM - 32
# Lucien Agoume - DM - 22
# Adrià Pedrosa - LB - 26
# Isaac Romero - CF - 24
# Chidera Ejuke - LW - 26
# Peque - SS - 22
# Tanguy Nianzou - CB - 22
# Djibril Sow - CM - 27
# Saúl Ñíguez - CM - 29
# Juanlu Sánchez - RB - 21
# Marcão - CB - 28
# Jesús Navas - RB - 38
# Kike Salas - CB - 22
# Lucas Ocampos - LW - 30
# Albert Sambi Lokonga - CM - 25
# Suso - RW - 30
# Gonzalo Montiel - RB - 27
# Pedro Ortiz - GK - 34
# Abel Ruiz - CF - 24
# Miguel Gutiérrez - LB - 23
# Daley Blind - CB - 34
# Iván Martín - AM - 25
# David López - CB - 35
# Yangel Herrera - CM - 26
# Bryan Gil - LW - 23
# Viktor Tsyhankov - RW - 26
# Alejandro Francés - CB - 22
# Oriol Romeu - DM - 33
# Arnau Martinez - RB - 21
# Yaser Asprilla - RW - 20
# Ladislav Krejčí - CB - 25
# Jhon Solis - CM - 20
# Donny van de Beek - CM - 27
# Portu - RW - 32
# Juanpe - CB - 33
# Cristhian Stuani - CF - 38
# Omar El Hilali - RB - 21
# Alex Král - CM - 26
# Carlos Romero - Attack - -
# Marash Kumbulla - CB - 24
# Javi Puado - LW - 26
# Alejo Véliz - CF - 21
# Jofre - RW - 23
# José Gragera - CM - 24
# Álvaro Tejero - RB - 28
# Leandro Cabrera - CB - 33
# Pol Lozano - CM - 25
# Sergi Gómez - CB - 32
# Irvin Cardona - CF - 27
# Álvaro Aguado - CM - 28
# Fernando Calero - CB - 29
# Brian Oliván - LB - 30
# Pere Milla - LW - 32
# Salvi - RW - 34
# Azor Matusiwa - DM - 26
# Ludovic Blas - RW - 26
# Christopher Wooh - CB - 23
# Alidu Seidu - CB - 24
# Adrien Truffert - LB - 22
# Albert Grønbaek - CM - 23
# Leo Skiri Østigård - CB - 24
# Lorenz Assignon - RB - 24
# Arnaud Kalimuendo - CF - 22
# Amine Gouiri - CF - 24
# Hans Hateboer - RB - 30
# Glen Kamara - CM - 29
# Baptiste Santamaria - DM - 29
# Benjamin Bourigeaud - CM - 30
# Carlos Gómez - RW - 22
# Jordan James - CM - 20
# Martín Zubimendi - DM - 25
# Sergio Gómez - RW - 24
# Takefusa Kubo - RW - 23
# Igor Zubeldia - CB - 27
# Javi López - LB - 22
# Sheraldo Becker - LW - 29
# Mikel Oyarzabal - CF - 27
# Jon Aramburu - RB - 22
# Beñat Turrientes - CM - 22
# Nayef Aguerd - CB - 28
# Luka Sučić - CM - 22
# Jon Pacheco - CB - 23
# Brais Méndez - AM - 27
# Hamari Traoré - RB - 32
# Aritz Elustondo - CB - 30
# Ander Barrenetxea - LW - 22
# Umar Sadiq - CF - 27
# Aihen Muñoz - LB - 27
# Álvaro Odriozola - RB - 28
# Ko Itakura - CB - 27
# Luca Netz - LB - 21
# Tim Kleindienst - CF - 29
# Joe Scally - RB - 21
# Kevin Stöger - AM - 31
# Julian Weigl - DM - 29
# Nico Elvedi - CB - 28
# Alassane Pléa - CF - 31
# Philipp Sander - CM - 26
# Franck Honorat - RW - 28
# Rocco Reitz - CM - 22
# Nathan N'Goumou - XX - XX
# Robin Hack - LW - 26
# Tomáš Čvančara - CF - 24
# Marvin Friedrich - CB - 28
# Florian Neuhaus - CM - 27
# Stefan Lainer - RB - 32
# Brendan Chardonnet - CB - 29
# Kenny Lala - RB - 33
# Mahdi Camara - CM - 26
# Ludovic Ajorque - CF - 30
# Hugo Magnetti - CM - 26
# Julien Le Cardinal - CB - 27
# Romain Del Castillo - RW - 28
# Jordan Amavi - LB - 30
# Jonas Martin - DM - 34
# Mathias Pereira Lage - LW - 27
# Romain Faivre - RM - 26
# Abdallah Sima - RW - 23
# Kamory Doumbia - AM - 21
# Abdoulaye Niakhate Ndiaye - CB - 22
# Edimilson Fernandes - DM - 28
# Soumaïla Coulibaly - CB - 21
# Ibrahim Salah - LW - 23
# Jérémy Le Douaron - LW - 26
# Pierre Lees-Melou - DM - 31
# Hianga Mananga Mbock - XX - XX
# Gautier Lloris - CB - 29
# Abdoulaye Touré - DM - 30
# Christopher Operi - LB - 27
# Loïc Nego - RB - 33
# Arouna Sangante - CB - 22
# Yassine Kechta - CM - 22
# Josué Casimir - RW - 23
# Issa Soumaré - LW - 24
# Oussama Targhalline - CM - 22
# Etienne Youte Kinkoue - CB - 22
# Rassoul Ndiaye - CM - 22
# Daler Kuzyaev - CM - 31
# Antoine Joujou - LW - 21
# Yoann Salmier - CB - 31
# Emmanuel Sabbi - RW - 26
# Samuel Grandsir - RW - 28
# Kandet Diawara - LW - 24
# Dylan Batubinsika - CB - 28
# Zuriko Davitashvili - RW - 23
# Mathis Amougou - CM - 18
# Ibrahim Sissoko - CF - 28
# Yunis Abdelhamid - CB - 37
# Mathieu Cafaro - RW - 27
# Dennis Appiah - RB - 32
# Pierre Ekwah Elimby - DM - 22
# Aimen Moueffek - CM - 23
# Léo Pétrot - CB - 27
# Mickael Nade - CB - 25
# Florian Tardieu - CM - 32
# Lucas Stassin - CF - 19
# Yvann Macon - RB - 26
# Lamine Fomba - DM - 26
# Louis Mouton - DM - 22
# Benjamin Bouchouari - CM - 22
# Luis Milla - CM - 58
# Chrisantus Uche - licensed - XX
# Djené - CB - 32
# Omar Alderete - CB - 27
# Diego Rico - LB - 31
# Alex Sola - RW - 25
# Iglesias - CB - 34
# Carles Pérez - RW - 26
# Bertuğ Yıldırım - CF - 22
# Mauro Arambarri - CM - 29
# Juan Berrocal - CB - 25
# Carles Aleñá - CM - 26
# Jesús Santiago - CM - 20
# Peter Federico - RW - 22
# Borja Mayoral - CF - 27
# Sergi - DM - 36
# Valentin Rosier - RB - 28
# Seydouba Cissé - CM - 23
# Javi Hernández - LB - 26
# Juan Cruz - CF - 29
# Jorge Sáenz - CB - 27
# Darko Brašanac - CM - 32
# Miguel - RW - 30
# Yvan Neyou - DM - 27
# Enric Franquesa - LB - 27
# Óscar Rodríguez Arnaiz - AM - 26
# Roberto López - AM - 24
# Matija Nastasić - CB - 31
# Renato Tapia - DM - 29
# Adrià Altimira - RB - 23
# Aritz Arambarri - CB - 26
# Munir El Haddadi - RW - 29
# Dani Raba - RW - 29
# Julián Chicco - DM - 26
# Diego - CF - 45
# Wout Faes - CB - 26
# James Justin - RB - 26
# Victor Bernth Kristiansen - XX - XX
# Wilfred Ndidi - DM - 27
# Jamie Vardy - CF - 37
# Harry Winks - DM - 28
# Caleb Okoli - CB - 23
# Stephy Mavididi - LW - 26
# Facundo Buonanotte - AM - 19
# Jordan Ayew - CF - 33
# Jordan Ayew - CF - 33
# Oliver Skipp - DM - 24
# Abdul Fatawu Issahaku - RW - 20
# Jannik Vestergaard - CB - 32
# Bobby Reid - RW - 31
# Bilal El Khannouss - AM - 20
# Odsonne Édouard - CF - 26
# Odsonne Édouard - CF - 26
# Hamza Choudhury - DM - 27
# Boubakary Soumaré - DM - 25
# Kasey McAteer - RW - 22
# Conor Coady - CB - 31
# Thomas Cannon - CF - 21
# Ricardo Pereira - RB - 31
# Elisha Owusu - DM - 26
# Lassine Sinayoko - LW - 24
# Gabriel Osho - CB - 26
# Jubal - CB - 31
# Clément Akpa - LB - 22
# Ki-Jana Hoever - RB - 22
# Paul Joly - RB - 24
# Rayan Raveloson - CM - 27
# Sinaly Diomande - CB - 23
# Gaëtan Perrin - RW - 28
# Ado Onaiwu - CF - 28
# Florian Ayé - CF - 27
# Gideon Mensah - LB - 26
# Théo Pellenard - CB - 30
# Assane Dioussé - DM - 27
# Adrian Bernabe - CM - 23
# Botond Balogh - CB - 22
# Dennis Man - RW - 26
# Ange-Yoan Bonny - CF - 21
# Woyo Coulibaly - RB - 25
# Simon Sohm - CM - 23
# Valentin Mihaila - LW - 24
# Emanuele Valeri - LB - 25
# Enrico Del Prato - RB - 24
# Alessandro Circati - CB - 21
# Hernani - CM - 30
# Matteo Cancellieri - RW - 22
# Yordan Osorio - CB - 30
# Nahuel Estévez - DM - 28
# Pontus Almqvist - RW - 25
# Gabriel Charpentier - CF - 25
# Drissa Camara - CM - 22
# Wylan Cyprien - CM - 29
# Mandela Keita - DM - 22
# Gianluca Di Chiara - LB - 30
# Giovanni Leoni - CB - 17
# Sebastiano Luperto - CB - 28
# Gabriele Zappa - RB - 24
# Roberto Piccoli - CF - 23
# Yerry Mina - CB - 30
# Tommaso Augello - LB - 30
# Zito Luvumbo - CF - 22
# Răzvan Marin - DM - 28
# Alessandro Deiola - CM - 29
# Paulo Azzi - LB - 30
# Nadir Zortea - RM - 25
# Antoine Makoumbou - DM - 26
# Matteo Prati - DM - 20
# Nicolas Viola - LW - 33
# Adam Obert - CB - 22
# Mateusz Wieteska - CB - 27
# Leonardo Pavoletti - CF - 35
# Gianluca Lapadula - CF - 34
# Mattia Felici - LW - 23
# Pantelis Hatzidiakos - CB - 27
# Jakub Jankto - LM - 28
# Gastón Pereiro - AM - 29
# Rasmus Nicolaisen - CB - 27
# Yann Gboho - LW - 23
# Vincent Sierro - CM - 29
# Cristian Cásseres Jr. - CM - 24
# Zakaria Aboukhlal - RW - 24
# Aron Dønnum - RW - 26
# Mark McKenzie - CB - 25
# Waren Kamanzi - XX - XX
# Djibril Sidibé - RB - 32
# Frank Magri - CF - 25
# Gabriel Suazo - LB - 27
# Shavy Babicka - RW - 24
# Niklas Schmidt - CM - 26
# Mamady Bangré - RW - 23
# James Tarkowski - CB - 31
# Dwight McNeil - LW - 24
# Dominic Calvert-Lewin - CF - 27
# Michael Keane - CB - 31
# Iliman Ndiaye - CF - 24
# Jack Harrison - RW - 27
# Ashley Young - LB - 39
# Abdoulaye Doucouré - CM - 31
# Vitaliy Mykolenko - LB - 25
# Tim Iroegbunam - CM - 21
# Idrissa Gana Gueye - CM - 35
# James Garner - DM - 23
# Jesper Lindstrøm - AM - 24
# Jarrad Branthwaite - CB - 22
# Séamus Coleman - RB - 36
# Beto - GK - 42
# Jake O'Brien - CB - 23
# Mason Holgate - CB - 28
# Federico Baschirotto - CB - 28
# Gaspar - CB - 33
# Antonino Gallo - LB - 24
# Nikola Krstović - CF - 24
# Ylber Ramadani - DM - 28
# Patrick Dorgu - LW - 20
# Balthazar Pierret - DM - 24
# Tete Morente - LW - 27
# Frederic Guilbert - RB - 29
# Lassana Coulibaly - CM - 28
# Lameck Banda - LW - 23
# Hamza Rafia - CM - 25
# Valentin Gendrey - RB - 24
# Valentin Gendrey - RB - 24
# Remi Oudin - AM - 27
# Gaby Jean - CB - 24
# Andy Pelmard - CB - 24
# Þórir Jóhann Helgason - XX - XX
# Nicola Sansone - LW - 33
# Koni De Winter - CB - 22
# Johan Vásquez - CB - 26
# Aarón Martín - LB - 27
# Morten Frendrup - CM - 23
# Milan Badelj - DM - 35
# Andrea Pinamonti - CF - 25
# Mattia Bani - CB - 30
# Stefano Sabelli - RB - 31
# Alessandro Zanoli - RB - 24
# Alessandro Vogliacco - CB - 26
# Junior Messias - RW - 33
# Morten Thorsby - CM - 28
# Ruslan Malinovskyi - AM - 31
# Caleb Ekuban - CF - 30
# Fabio Miretti - CM - 21
# Emil Bohinen - DM - 25
# Filippo Melegoni - CM - 25
# Brooke Norton-Cuffy - RB - 20
# Alessandro Marcandalli - CB - 22
# Patrizio Masini - CM - 23
# Jackson Irvine - CM - 31
# Karol Mets - CB - 31
# Hauke Wahl - CB - 30
# Philipp Treu - RB - 23
# Eric Smith - CB - 27
# Johannes Eggestein - CF - 26
# Robert Wagner - CM - 21
# Elias Saad - LW - 24
# Oladapo Afolayan - RW - 27
# Manolis Saliakas - RB - 28
# Morgan Guilavogui - CF - 26
# Lars Ritzka - LB - 26
# Connor Metcalfe - CM - 24
# Adam Dźwigała - CB - 29
# Cristhian Mosquera - CB - 20
# José Luis García Vayá - DM - 26
# Diego López - GK - 42
# Thierry Correia - RB - 25
# César Tárrega - CB - 22
# Jesus Vazquez - LB - 21
# Hugo Duro - CF - 24
# Domingos André Ribeiro Almeida - AM - 24
# Javier Guerra - CM - 21
# Dimitri Foulquier - RB - 31
# Hugo Guillamón - DM - 24
# Dani Gómez - CF - 26
# Yarek Gasiorowski - CB - 19
# Rafa Mir - CF - 27
# Enzo Barrenechea - DM - 23
# Sergi Canós - RW - 27
# Francisco Perez - RW - 22
# Germán Valera - RW - 22
# Maximiliano Caufriez - CB - 27
# Cenk Özkacar - CB - 24
# Cenk Özkacar - CB - 24
# Modibo Sagnan - CB - 25
# Téji Savanier - AM - 32
# Falaye Sacko - RB - 29
# Akor Adams - CF - 24
# Arnaud Nordin - RW - 26
# Becir Omeragic - CB - 22
# Joris Chotard - DM - 23
# Enzo Tchato - RB - 21
# Tanguy Coulibaly - RW - 23
# Jordan Ferri - CM - 32
# Khalil Fayad - CM - 20
# Lucas Mincarelli - LB - 20
# Wahbi Khazri - LW - 33
# Musa Al-Taamari - XX - XX
# Boubakar Kouyaté - CB - 27
# Issiaga Sylla - LB - 30
# Gabriel Bares - DM - 24
# Kevin Akpoguma - CB - 29
# Alexander Prass - LM - 23
# Marius Bülter - LW - 31
# Anton Stach - CM - 25
# Pavel Kadeřábek - RB - 32
# Andrej Kramarić - CF - 33
# Tim Drexler - CB - 19
# Adam Hložek - SS - 22
# Florian Grillitsch - DM - 29
# Tom Bischof - AM - 19
# Grischa Prömel - CM - 29
# Umut Tohumcu - CM - 20
# Robin Hranáč - CB - 24
# Stanley N'Soki - XX - XX
# Jacob Bruun Larsen - LW - 26
# Haris Tabakovic - CF - 30
# David Jurásek - LB - 24
# Gaetano Oristanio - AM - 22
# Francesco Zampano - LB - 31
# Michael Svoboda - CB - 26
# Antonio Candela - RB - 24
# Jay Idzes - CB - 24
# Mikael Ellertsson - CM - 22
# Joel Pohjanpalo - CF - 30
# Marin Šverko - CB - 26
# Gianluca Busio - CM - 22
# Alfred Duncan - CM - 31
# Hans Nicolussi Caviglia - CM - 24
# Magnus Kofod Andersen - CM - 25
# Ridgeciano Haps - LB - 31
# Giorgio Altare - CB - 26
# Christian Gytkjær - XX - XX
# Joël Schingtienne - CB - 22
# Richie Sagrado - RB - 20
# Nicholas Pierini - RW - 26
# Antonio Raimondo - CF - 20
# Domen Črnigoj - CM - 28
# Nunzio Lella - CM - 24
# Franco Carboni - LB - 21
# Lorenzo Lucchesi - CB - 21
# Leif Davis - LB - 24
# Jacob Greaves - CB - 24
# Sam Morsy - CM - 33
# Omari Hutchinson - RW - 21
# Liam Delap - CF - 21
# Axel Tuanzebe - CB - 26
# Dara O'Shea - CB - 25
# Sammie Szmodics - AM - 29
# Kalvin Phillips - DM - 28
# Wes Burns - RW - 29
# Luke Woolfenden - CB - 26
# Jack Clarke - LW - 23
# Ben Johnson - RB - 24
# Chiedozie Ogbene - RW - 27
# Massimo Luongo - CM - 32
# Conor Chaplin - SS - 27
# Jens Cajuste - DM - 25
# Jack Taylor - CM - 26
# George Hirst - CF - 25
# Marcus Harness - LW - 28
# George Edmundson - CB - 27
# Cameron Burgess - CB - 29
# Harry Clarke - RB - 23
# Conor Townsend - LB - 31
# Lucas Oliveira Rosa - RB - 24
# Luis Pérez - CF - -
# Eray Cömert - CB - 26
# Kike Pérez - CM - 27
# Selim Amallah - AM - 27
# Raúl Moro - LW - 21
# Stanko Jurić - DM - 28
# Amath - RW - 28
# Darwin Machís - LW - 31
# Juanmi Latasa - CF - 23
# David Torres - CB - 21
# Javi Sánchez - CB - 27
# Iván Sánchez - CF - 44
# Víctor Meseguer - CM - 25
# Mamadou Sylla - CF - 30
# Anuar - LW - 29
# Kenedy - LW - 28
# César de la Hoz - DM - 32
# Giorgos Kyriakopoulos - LM - 28
# Pablo Marí - CB - 31
# Armando Izzo - CB - 32
# Matteo Pessina - CM - 27
# Daniel Maldini - AM - 23
# Warren Bondo - CM - 21
# Milan Đurić - XX - XX
# Andrea Carboni - CB - 23
# Pedro Pereira - CF - 31
# Dany Mota - SS - 26
# Luca Caldirola - CB - 33
# Andrea Petagna - CF - 29
# Samuele Birindelli - RB - 25
# Roberto Gagliardini - CM - 30
# Danilo D'Ambrosio - CB - 36
# Patrick Ciurria - RM - 29
# Marco D'Alessandro - RW - 33
# Mattia Valoti - CM - 31
# Marc Guéhi - CB - 24
# Eberechi Eze - AM - 26
# Tyrick Mitchell - LB - 25
# Daniel Muñoz - RB - 28
# Adam Wharton - DM - 20
# Jean-Philippe Mateta - CF - 27
# Daichi Kamada - AM - 28
# Maxence Lacroix - CB - 24
# Chris Richards - CB - 24
# Jefferson Lerma - DM - 30
# Will Hughes - CM - 29
# Nathaniel Clyne - RB - 33
# Ismaila Sarr - RW - 26
# Chadi Riad - CB - 21
# Trevoh Chalobah - CB - 25
# Jeffrey Schlupp - LM - 31
# Joel Ward - RB - 35
# Jordan Lefort - CB - 31
# Himad Abdelli - AM - 24
# Carlens Arcus - RB - 28
# Jean-Eudes Aholou - DM - 30
# Florent Hanin - LB - 34
# Farid El Melali - LW - 27
# Cédric Hountondji - CB - 30
# Abdoulaye Bamba - CB - 34
# Jacques Ekomie - LB - 21
# Jim Allevinah - RW - 29
# Bamba Dieng - CF - 24
# Zinedine Ferhat - RW - 31
# Pierrick Capelle - CM - 37
# Esteban Lepaul - CF - 24
# Lilian Raolisoa - RB - 24
# Zinédine Ould Khaled - DM - 24
# Lois Diony - CF - 31
# Joseph Lopy - CM - 32
# Alberto Moleiro - AM - 21
# Kirian Rodríguez - AM - 28
# Oliver McBurnie - XX - XX
# Javier Muñoz - SS - 44
# Álex Suárez - CB - 31
# Álex Muñoz - LB - 30
# Mika Màrmol - CB - 23
# Marvin - LB - 32
# Sandro Ramírez - CF - 29
# Scott McKenna - CB - 27
# Juan Herzog - licensed - XX
# Fábio Silva - CF - 22
# Dario Essugo - DM - 19
# Viti - CM - 24
# Enzo Loiodice - CM - 23
# Jaime Mata - CF - 36
# Benito Ramírez - LW - 29
# Manuel Fuster - LW - 27
# Marc Cardona - CF - 29
# Iván Gil - AM - 24
# Timo Becker - CB - 27
# Magnus Knudsen - CM - 23
# Lewis Holtby - CM - 34
# Benedikt Pichler - CF - 27
# Finn Porath - AM - 27
# Shuto Machino - CF - 25
# Carl Johansson - CB - 30
# Patrick Erras - DM - 29
# Marko Ivezić - DM - 22
# Alexander Bernhardsson - RW - 26
# Tymoteusz Puchacz - LB - 25
# Marco Komenda - CB - 27
# Nicolai Remberg - CM - 24
# Steven Skrzybski - AM - 31
# Jann-Fiete Arp - CF - 24
# Marvin Schulz - DM - 29
# Felix Passlack - RB - 26
# Maximilian Wittek - LB - 29
# Jakov Medić - CB - 26
# Ibrahima Sissoko - DM - 27
# Matúš Bero - CM - 29
# Dani de Wit - AM - 26
# Philipp Hofmann - CF - 31
# Anthony Losilla - DM - 38
# Erhan Mašović - CB - 25
# Moritz Broschinski - CF - 24
# Lukas Daschner - AM - 26
# Tim Oermann - CB - 21
# Ivan Ordets - CB - 32
# Koji Miyoshi - RM - 27
# Cristian Gamboa - RB - 35
# Flynn Downes - DM - 25
# Jan Bednarek - CB - 28
# Yukinari Sugawara - RB - 24
# Taylor Harwood-Bellis - CB - 22
# Kyle Walker-Peters - RB - 27
# Ben Brereton - CF - 25
# Mateus Fernandes - CM - 20
# Joe Aribo - CM - 28
# Jack Stephens - CB - 30
# Adam Armstrong - CF - 27
# William Smallbone - CM - 24
# Cameron Archer - CF - 22
# Charlie Taylor - LB - 31
# Ryan Fraser - LW - 30
# Adam Lallana - AM - 36
# Ryan Manning - LB - 28
# Samuel Edozie - LW - 21
# Carlos Alcaraz - CM - 21
# James Bree - RB - 26
# Nathan Wood-Gordon - CB - 22
# Mario Lemina - DM - 31
# João Gomes - CM - 23
# Jørgen Strand Larsen - CF - 24
# Rayan Aït-Nouri - LB - 23
# Matheus Cunha - CF - 25
# Jean-Ricner Bellegarde - CM - 26
# Toti Gomes - CB - 25
# Yerson Mosquera - CB - 23
# Nélson Semedo - RB - 30
# Craig Dawson - CB - 34
# André - CM - 40
# Hwang Hee-chan - XX - XX
# Matt Doherty - RB - 32
# Rodrigo Gomes - RM - 21
# Carlos Forbs - LW - 20
# Santiago Bueno - CB - 25
# Gonçalo Guedes - LW - 27
# Tommy Doyle - CM - 23
# Daniel Podence - RW - 29
# Pablo Sarabia - RW - 32
# Boubacar Traoré - DM - 23
# Toni Kroos - CM - 34
# Updated scouting report saved to 'updated_scouting_report.csv'

# %%
import pandas as pd

# Load both CSV files
updated_report_path = '../../data/updated_scouting_report.csv'
cleaned_report_path = '../../data/cleaned_scouting_report copy.csv'

updated_scouting_df = pd.read_csv(updated_report_path)
cleaned_scouting_df = pd.read_csv(cleaned_report_path)

# Merge the dataframes on 'player_name' with 'Position' and 'Age' from the updated report
merged_df = cleaned_scouting_df.merge(
    updated_scouting_df[['player_name', 'Position', 'Age']],
    on='player_name',
    how='left',
    suffixes=('', '_updated')
)

# Update 'Position' column with values from 'Position_updated' and add 'Age'
merged_df['Position'] = merged_df['Position_updated'].combine_first(merged_df['Position'])
merged_df.drop(columns=['Position_updated'], inplace=True)

# Save the merged result
merged_report_path = '../../data/cleaned_scouting_report_with_age.csv'
merged_df.to_csv(merged_report_path, index=False)

print(f"Merged report saved to '{merged_report_path}'")
# Out:
# Merged report saved to '../../data/cleaned_scouting_report_with_age.csv'
