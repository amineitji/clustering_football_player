# %% [markdown]
# # **Clustering Top 5 football players**

# %% [markdown]
# ### Les imports

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import csv
import os
import time
import re

# %% [markdown]
# ### Récuparation de tous les liens des équipes du top 5 européen

# %%
class TeamScraper:
    def __init__(self, url):
        self.url = url

    def scrape_teams(self):
        response = requests.get(self.url)
        soup = BeautifulSoup(response.content, 'html.parser')
        team_table = soup.find('table', {'id': 'big5_table'})
        teams_data = []

        for row in team_table.find('tbody').find_all('tr'):
            team_cell = row.find('td', {'data-stat': 'team'})
            if team_cell:
                team_name = team_cell.get_text(strip=True)
                team_link = 'https://fbref.com' + team_cell.find('a')['href'] + '/'
                teams_data.append([team_name, team_link])

        # Save team data to CSV
        with open('../data/teams_data.csv', mode='w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(['Team Name', 'Team URL'])
            writer.writerows(teams_data)

        print("Teams data saved to teams_data.csv")

# %%
team_scraper = TeamScraper('https://fbref.com/en/comps/Big5/Big-5-European-Leagues-Stats')
team_scraper.scrape_teams()
# Out:
# Teams data saved to teams_data.csv

# %% [markdown]
# ### Récuparation de tous les liens des joueurs de chaque équipe

# %%
import csv
import requests
from bs4 import BeautifulSoup
import time

class PlayerScraper:
    def __init__(self, teams_file):
        self.teams_file = teams_file

    def scrape_players(self):
        # Open the output CSV file in append mode (use mode='a')
        output_file = '../../data/players_data.csv'
        
        # Open CSV file once outside the player loop
        with open(output_file, mode='a', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(['Player Name', 'Position', 'Player URL', 'Team Name'])  # Updated header to include Team Name

            # Open the teams file and iterate through teams
            with open(self.teams_file, newline='') as csvfile:
                reader = csv.reader(csvfile)
                next(reader)  # Skip header row
                
                # Loop through each team
                for row in reader:
                    team_name, team_url = row
                    print(f"Scraping players from {team_name}...")

                    # Fetch the page content and parse it
                    response = requests.get(team_url)
                    soup = BeautifulSoup(response.content, 'html.parser')

                    # Find the player table
                    player_table = soup.find('table', {'class': 'stats_table sortable min_width'})

                    # Iterate through player rows
                    for player_row in player_table.find('tbody').find_all('tr'):

                        # Extract player name from the <th> element
                        player_name = player_row.find('th', {'data-stat': 'player'}).get_text(strip=True)

                        # Extract player position from the <td> element
                        player_position = player_row.find('td', {'data-stat': 'position'}).get_text(strip=True)

                        # Extract the player link from the <a> inside the <th> element
                        player_link = player_row.find('th', {'data-stat': 'player'}).find('a')['href']
                        player_link = 'https://fbref.com' + player_link
                        print(player_name, " - ", player_position, "- ", player_link, " - ",team_name)

                        # Write player data along with team name to the CSV file
                        writer.writerow([player_name, player_position, player_link, team_name])

                    # Add a delay after each request to avoid being blocked (5 requests per minute = 12 seconds delay)
                    time.sleep(12)

        print(f"Players data saved to {output_file}")

# %%
player_scraper = PlayerScraper('../../data/teams_data.csv')
player_scraper.scrape_players()
# Out:
# Scraping players from Monaco...
# Philipp Köhn  -  GK -  https://fbref.com/en/players/ff74841d/Philipp-Kohn  -  Monaco
# Denis Zakaria  -  MF -  https://fbref.com/en/players/384d58d9/Denis-Zakaria  -  Monaco
# Eliesse Ben Seghir  -  MF,FW -  https://fbref.com/en/players/3bd65247/Eliesse-Ben-Seghir  -  Monaco
# Vanderson  -  DF -  https://fbref.com/en/players/ee45fd85/Vanderson  -  Monaco
# Thilo Kehrer  -  DF -  https://fbref.com/en/players/51dbeea9/Thilo-Kehrer  -  Monaco
# Takumi Minamino  -  MF -  https://fbref.com/en/players/f833a830/Takumi-Minamino  -  Monaco
# Lamine Camara  -  MF -  https://fbref.com/en/players/19c2ffa4/Lamine-Camara  -  Monaco
# Folarin Balogun  -  FW -  https://fbref.com/en/players/31822f8c/Folarin-Balogun  -  Monaco
# Maghnes Akliouche  -  FW,MF -  https://fbref.com/en/players/b625b241/Maghnes-Akliouche  -  Monaco
# Mohammed Salisu  -  DF -  https://fbref.com/en/players/0b33f6ad/Mohammed-Salisu  -  Monaco
# Wilfried Singo  -  DF -  https://fbref.com/en/players/8b609c34/Wilfried-Singo  -  Monaco
# Breel Embolo  -  FW -  https://fbref.com/en/players/0b4f388a/Breel-Embolo  -  Monaco
# Caio Henrique Oliveira Silva  -  DF -  https://fbref.com/en/players/30af8b93/Caio-Henrique-Oliveira-Silva  -  Monaco
# Aleksandr Golovin  -  MF -  https://fbref.com/en/players/3708e9fa/Aleksandr-Golovin  -  Monaco
# Ismail Jakobs  -  DF -  https://fbref.com/en/players/a0415710/Ismail-Jakobs  -  Monaco
# Soungoutou Magassa  -  MF -  https://fbref.com/en/players/dfc5d4fa/Soungoutou-Magassa  -  Monaco
# Jordan Teze  -  DF -  https://fbref.com/en/players/82e9b1bb/Jordan-Teze  -  Monaco
# Christian Mawissa  -  DF -  https://fbref.com/en/players/2c70d915/Christian-Mawissa  -  Monaco
# Kassoum Ouattara  -  DF,FW -  https://fbref.com/en/players/6620c21a/Kassoum-Ouattara  -  Monaco
# George Ilenikhena  -  FW,MF -  https://fbref.com/en/players/78c3ad07/George-Ilenikhena  -  Monaco
# Krépin Diatta  -  DF -  https://fbref.com/en/players/8104e41e/Krepin-Diatta  -  Monaco
# Eliot Matazo  -  MF -  https://fbref.com/en/players/15944afd/Eliot-Matazo  -  Monaco
# Edan Diop  -  MF -  https://fbref.com/en/players/37143438/Edan-Diop  -  Monaco
# Yann Liénard  -  GK -  https://fbref.com/en/players/5216036b/Yann-Lienard  -  Monaco
# Radosław Majecki  -  GK -  https://fbref.com/en/players/20de219a/Radoslaw-Majecki  -  Monaco
# Guillermo Maripán  -  DF -  https://fbref.com/en/players/d9764034/Guillermo-Maripan  -  Monaco
# Scraping players from Paris S-G...
# Willian Pacho  -  DF -  https://fbref.com/en/players/ecbe2839/Willian-Pacho  -  Paris S-G
# Achraf Hakimi  -  DF -  https://fbref.com/en/players/e42d61c7/Achraf-Hakimi  -  Paris S-G
# João Neves  -  MF -  https://fbref.com/en/players/c2a15a27/Joao-Neves  -  Paris S-G
# Warren Zaïre-Emery  -  MF,DF -  https://fbref.com/en/players/6b9960cf/Warren-Zaire-Emery  -  Paris S-G
# Bradley Barcola  -  FW -  https://fbref.com/en/players/a0d55a09/Bradley-Barcola  -  Paris S-G
# Gianluigi Donnarumma  -  GK -  https://fbref.com/en/players/08f5afaa/Gianluigi-Donnarumma  -  Paris S-G
# Marquinhos  -  DF -  https://fbref.com/en/players/d5f2f82b/Marquinhos  -  Paris S-G
# Lucas Beraldo  -  DF -  https://fbref.com/en/players/b8aedf06/Lucas-Beraldo  -  Paris S-G
# Ousmane Dembélé  -  FW -  https://fbref.com/en/players/b19db005/Ousmane-Dembele  -  Paris S-G
# Lee Kang-in  -  FW,MF -  https://fbref.com/en/players/8455ad90/Lee-Kang-in  -  Paris S-G
# Vitinha  -  MF -  https://fbref.com/en/players/3b029691/Vitinha  -  Paris S-G
# Marco Asensio  -  FW,MF -  https://fbref.com/en/players/45af8a54/Marco-Asensio  -  Paris S-G
# Fabián Ruiz Peña  -  MF -  https://fbref.com/en/players/c0c7ff58/Fabian-Ruiz-Pena  -  Paris S-G
# Nuno Mendes  -  DF -  https://fbref.com/en/players/f20e4cc9/Nuno-Mendes  -  Paris S-G
# Randal Kolo Muani  -  FW -  https://fbref.com/en/players/c0b3669f/Randal-Kolo-Muani  -  Paris S-G
# Matvei Safonov  -  GK -  https://fbref.com/en/players/d97b252e/Matvei-Safonov  -  Paris S-G
# Désiré Doué  -  FW -  https://fbref.com/en/players/9e7483ff/Desire-Doue  -  Paris S-G
# Milan Škriniar  -  DF -  https://fbref.com/en/players/30f5ffa9/Milan-Skriniar  -  Paris S-G
# Ibrahim Mbaye  -  FW,MF -  https://fbref.com/en/players/201b4ee4/Ibrahim-Mbaye  -  Paris S-G
# Yoram Zague  -  DF -  https://fbref.com/en/players/5ce497e2/Yoram-Zague  -  Paris S-G
# Gonçalo Ramos  -  FW -  https://fbref.com/en/players/f63cda26/Goncalo-Ramos  -  Paris S-G
# Senny Mayulu  -  MF,DF -  https://fbref.com/en/players/bac89b96/Senny-Mayulu  -  Paris S-G
# Naoufel El Hannach  -  DF -  https://fbref.com/en/players/f9b69340/Naoufel-El-Hannach  -  Paris S-G
# Carlos Soler  -  MF -  https://fbref.com/en/players/fed17f5a/Carlos-Soler  -  Paris S-G
# Arnau Tenas  -  GK -  https://fbref.com/en/players/30670b0e/Arnau-Tenas  -  Paris S-G
# Scraping players from Barcelona...
# Robert Lewandowski  -  FW -  https://fbref.com/en/players/8d78e732/Robert-Lewandowski  -  Barcelona
# Raphinha  -  FW,MF -  https://fbref.com/en/players/3423f250/Raphinha  -  Barcelona
# Jules Koundé  -  DF -  https://fbref.com/en/players/4d1666ff/Jules-Kounde  -  Barcelona
# Lamine Yamal  -  FW -  https://fbref.com/en/players/82ec26c1/Lamine-Yamal  -  Barcelona
# Iñigo Martínez  -  DF -  https://fbref.com/en/players/3fc45c73/Inigo-Martinez  -  Barcelona
# Pau Cubarsí  -  DF -  https://fbref.com/en/players/cc7888f3/Pau-Cubarsi  -  Barcelona
# Pedri  -  MF -  https://fbref.com/en/players/0d9b2d31/Pedri  -  Barcelona
# Alejandro Balde  -  DF -  https://fbref.com/en/players/5ccc9672/Alejandro-Balde  -  Barcelona
# Marc-André ter Stegen  -  GK -  https://fbref.com/en/players/6f51e382/Marc-Andre-ter-Stegen  -  Barcelona
# Marc Casado  -  MF -  https://fbref.com/en/players/2ef08833/Marc-Casado  -  Barcelona
# Ferrán Torres  -  FW -  https://fbref.com/en/players/9e1035f8/Ferran-Torres  -  Barcelona
# Eric García  -  MF -  https://fbref.com/en/players/2bed3eab/Eric-Garcia  -  Barcelona
# Iñaki Peña  -  GK -  https://fbref.com/en/players/cc1c5035/Inaki-Pena  -  Barcelona
# Gerard Martín  -  DF -  https://fbref.com/en/players/b792c59d/Gerard-Martin  -  Barcelona
# Marc Bernal  -  MF -  https://fbref.com/en/players/29117812/Marc-Bernal  -  Barcelona
# Pablo Torre  -  MF -  https://fbref.com/en/players/04e531b6/Pablo-Torre  -  Barcelona
# Dani Olmo  -  MF -  https://fbref.com/en/players/ae44e8e2/Dani-Olmo  -  Barcelona
# Sergi Dominguez  -  DF -  https://fbref.com/en/players/88507352/Sergi-Dominguez  -  Barcelona
# Pau Victor Delgado  -  FW -  https://fbref.com/en/players/e6e7c819/Pau-Victor-Delgado  -  Barcelona
# Héctor Fort  -  DF -  https://fbref.com/en/players/2e31f3a6/Hector-Fort  -  Barcelona
# Fermin López  -  MF -  https://fbref.com/en/players/c1fe5f0b/Fermin-Lopez  -  Barcelona
# Andreas Christensen  -  DF -  https://fbref.com/en/players/1cb49278/Andreas-Christensen  -  Barcelona
# Ansu Fati  -  FW -  https://fbref.com/en/players/0ba976e4/Ansu-Fati  -  Barcelona
# Frenkie de Jong  -  MF -  https://fbref.com/en/players/1bacc518/Frenkie-de-Jong  -  Barcelona
# Ander Astralaga  -  GK -  https://fbref.com/en/players/031e0283/Ander-Astralaga  -  Barcelona
# Andres Cuenca  -  DF -  https://fbref.com/en/players/2eefd1b3/Andres-Cuenca  -  Barcelona
# Guillermo Fernandez  -  MF -  https://fbref.com/en/players/4390bf25/Guillermo-Fernandez  -  Barcelona
# Toni Fernández  -  MF -  https://fbref.com/en/players/285ff324/Toni-Fernandez  -  Barcelona
# Diego Kochen  -  GK -  https://fbref.com/en/players/497144d6/Diego-Kochen  -  Barcelona
# Álex Valle  -  DF -  https://fbref.com/en/players/97022551/Alex-Valle  -  Barcelona
# Áron Yaakobishvili  -  GK -  https://fbref.com/en/players/0b8c9180/Aron-Yaakobishvili  -  Barcelona
# Scraping players from Bayern Munich...
# Joshua Kimmich  -  MF,DF -  https://fbref.com/en/players/49296448/Joshua-Kimmich  -  Bayern Munich
# Dayot Upamecano  -  DF -  https://fbref.com/en/players/d248cd8f/Dayot-Upamecano  -  Bayern Munich
# Kim Min-jae  -  DF -  https://fbref.com/en/players/e0f8151c/Kim-Min-jae  -  Bayern Munich
# Harry Kane  -  FW -  https://fbref.com/en/players/21a66f6a/Harry-Kane  -  Bayern Munich
# Manuel Neuer  -  GK -  https://fbref.com/en/players/8778c910/Manuel-Neuer  -  Bayern Munich
# Michael Olise  -  FW,MF -  https://fbref.com/en/players/c4486bac/Michael-Olise  -  Bayern Munich
# Aleksandar Pavlovic  -  MF -  https://fbref.com/en/players/2658c82f/Aleksandar-Pavlovic  -  Bayern Munich
# Serge Gnabry  -  FW,MF -  https://fbref.com/en/players/88e357ef/Serge-Gnabry  -  Bayern Munich
# Jamal Musiala  -  MF -  https://fbref.com/en/players/2c0558b8/Jamal-Musiala  -  Bayern Munich
# Alphonso Davies  -  DF -  https://fbref.com/en/players/d781d855/Alphonso-Davies  -  Bayern Munich
# Raphaël Guerreiro  -  DF -  https://fbref.com/en/players/048a1cbc/Raphael-Guerreiro  -  Bayern Munich
# Kingsley Coman  -  FW,MF -  https://fbref.com/en/players/042e8a49/Kingsley-Coman  -  Bayern Munich
# Sacha Boey  -  DF -  https://fbref.com/en/players/6c8ddd52/Sacha-Boey  -  Bayern Munich
# Thomas Müller  -  MF,FW -  https://fbref.com/en/players/3c6089ab/Thomas-Muller  -  Bayern Munich
# João Palhinha  -  MF -  https://fbref.com/en/players/a78ff07f/Joao-Palhinha  -  Bayern Munich
# Konrad Laimer  -  DF,MF -  https://fbref.com/en/players/c1b7847c/Konrad-Laimer  -  Bayern Munich
# Mathys Tel  -  MF,FW -  https://fbref.com/en/players/829aa60c/Mathys-Tel  -  Bayern Munich
# Sven Ulreich  -  GK -  https://fbref.com/en/players/7d3e7da6/Sven-Ulreich  -  Bayern Munich
# Leroy Sané  -  FW -  https://fbref.com/en/players/2b114be3/Leroy-Sane  -  Bayern Munich
# Eric Dier  -  DF -  https://fbref.com/en/players/ac861941/Eric-Dier  -  Bayern Munich
# Leon Goretzka  -  DF -  https://fbref.com/en/players/cc86b9a3/Leon-Goretzka  -  Bayern Munich
# Adam Aznou  -  DF -  https://fbref.com/en/players/e678d983/Adam-Aznou  -  Bayern Munich
# Daniel Peretz  -  GK -  https://fbref.com/en/players/3f29b3ba/Daniel-Peretz  -  Bayern Munich
# Scraping players from Liverpool...
# Virgil van Dijk  -  DF -  https://fbref.com/en/players/e06683ca/Virgil-van-Dijk  -  Liverpool
# Ryan Gravenberch  -  MF -  https://fbref.com/en/players/b8e740fb/Ryan-Gravenberch  -  Liverpool
# Mohamed Salah  -  FW -  https://fbref.com/en/players/e342ad68/Mohamed-Salah  -  Liverpool
# Trent Alexander-Arnold  -  DF -  https://fbref.com/en/players/cd1acf9d/Trent-Alexander-Arnold  -  Liverpool
# Alexis Mac Allister  -  MF -  https://fbref.com/en/players/83d074ff/Alexis-Mac-Allister  -  Liverpool
# Ibrahima Konaté  -  DF -  https://fbref.com/en/players/5ed9b537/Ibrahima-Konate  -  Liverpool
# Dominik Szoboszlai  -  MF -  https://fbref.com/en/players/934e1968/Dominik-Szoboszlai  -  Liverpool
# Alisson  -  GK -  https://fbref.com/en/players/7a2e46a8/Alisson  -  Liverpool
# Andrew Robertson  -  DF -  https://fbref.com/en/players/2e4f5f03/Andrew-Robertson  -  Liverpool
# Diogo Jota  -  FW -  https://fbref.com/en/players/178ae8f8/Diogo-Jota  -  Liverpool
# Luis Díaz  -  FW -  https://fbref.com/en/players/4a1a9578/Luis-Diaz  -  Liverpool
# Cody Gakpo  -  FW -  https://fbref.com/en/players/1971591f/Cody-Gakpo  -  Liverpool
# Curtis Jones  -  MF -  https://fbref.com/en/players/4fb9c88f/Curtis-Jones  -  Liverpool
# Darwin Núñez  -  FW -  https://fbref.com/en/players/4d77b365/Darwin-Nunez  -  Liverpool
# Kostas Tsimikas  -  DF -  https://fbref.com/en/players/f315ca93/Kostas-Tsimikas  -  Liverpool
# Caoimhín Kelleher  -  GK -  https://fbref.com/en/players/62d7ef38/Caoimhin-Kelleher  -  Liverpool
# Jarell Quansah  -  DF -  https://fbref.com/en/players/4125cb98/Jarell-Quansah  -  Liverpool
# Conor Bradley  -  DF -  https://fbref.com/en/players/bbd67769/Conor-Bradley  -  Liverpool
# Federico Chiesa  -  FW -  https://fbref.com/en/players/b0f7e36c/Federico-Chiesa  -  Liverpool
# Vitezslav Jaros  -  GK -  https://fbref.com/en/players/12bb4d6a/Vitezslav-Jaros  -  Liverpool
# Harvey Elliott  -  FW -  https://fbref.com/en/players/b9e1436c/Harvey-Elliott  -  Liverpool
# Wataru Endo  -  MF -  https://fbref.com/en/players/c149016b/Wataru-Endo  -  Liverpool
# Joe Gomez  -  DF -  https://fbref.com/en/players/7a11550b/Joe-Gomez  -  Liverpool
# Scraping players from Arsenal...
# Kai Havertz  -  FW,MF -  https://fbref.com/en/players/fed7cb61/Kai-Havertz  -  Arsenal
# Gabriel Magalhães  -  DF -  https://fbref.com/en/players/67ac5bb8/Gabriel-Magalhaes  -  Arsenal
# David Raya  -  GK -  https://fbref.com/en/players/98ea5115/David-Raya  -  Arsenal
# William Saliba  -  DF -  https://fbref.com/en/players/972aeb2a/William-Saliba  -  Arsenal
# Thomas Partey  -  MF,DF -  https://fbref.com/en/players/529f49ab/Thomas-Partey  -  Arsenal
# Bukayo Saka  -  MF,FW -  https://fbref.com/en/players/bc7dc64d/Bukayo-Saka  -  Arsenal
# Declan Rice  -  MF -  https://fbref.com/en/players/1c7012b8/Declan-Rice  -  Arsenal
# Jurriën Timber  -  DF -  https://fbref.com/en/players/41034650/Jurrien-Timber  -  Arsenal
# Gabriel Martinelli  -  MF,FW -  https://fbref.com/en/players/48a5a5d6/Gabriel-Martinelli  -  Arsenal
# Ben White  -  DF -  https://fbref.com/en/players/35e413f1/Ben-White  -  Arsenal
# Leandro Trossard  -  FW -  https://fbref.com/en/players/38ceb24a/Leandro-Trossard  -  Arsenal
# Riccardo Calafiori  -  DF -  https://fbref.com/en/players/aded8e6f/Riccardo-Calafiori  -  Arsenal
# Martin Ødegaard  -  MF -  https://fbref.com/en/players/79300479/Martin-Odegaard  -  Arsenal
# Jorginho  -  MF -  https://fbref.com/en/players/45db685d/Jorginho  -  Arsenal
# Raheem Sterling  -  MF,FW -  https://fbref.com/en/players/b400bde0/Raheem-Sterling  -  Arsenal
# Gabriel Jesus  -  FW,MF -  https://fbref.com/en/players/b66315ae/Gabriel-Jesus  -  Arsenal
# Oleksandr Zinchenko  -  DF -  https://fbref.com/en/players/51cf8561/Oleksandr-Zinchenko  -  Arsenal
# Mikel Merino  -  MF -  https://fbref.com/en/players/d080ed5e/Mikel-Merino  -  Arsenal
# Jakub Kiwior  -  DF -  https://fbref.com/en/players/dc3e663e/Jakub-Kiwior  -  Arsenal
# Ethan Nwaneri  -  MF,FW -  https://fbref.com/en/players/7f94982c/Ethan-Nwaneri  -  Arsenal
# Takehiro Tomiyasu  -  DF -  https://fbref.com/en/players/b3af9be1/Takehiro-Tomiyasu  -  Arsenal
# Reiss Nelson  -  FW -  https://fbref.com/en/players/c5bdb6e3/Reiss-Nelson  -  Arsenal
# Myles Lewis-Skelly  -  DF -  https://fbref.com/en/players/5dff6c28/Myles-Lewis-Skelly  -  Arsenal
# Nathan Butler-Oyedeji  -  FW -  https://fbref.com/en/players/3a686640/Nathan-Butler-Oyedeji  -  Arsenal
# Ayden Heaven  -  MF -  https://fbref.com/en/players/64e17fab/Ayden-Heaven  -  Arsenal
# Ismeal Kabia  -  MF -  https://fbref.com/en/players/6b15cf32/Ismeal-Kabia  -  Arsenal
# Maldini Kacurri  -  DF -  https://fbref.com/en/players/7be4311f/Maldini-Kacurri  -  Arsenal
# Neto  -  GK -  https://fbref.com/en/players/a9dc785c/Neto  -  Arsenal
# Josh Nichols  -  DF -  https://fbref.com/en/players/676cf55d/Josh-Nichols  -  Arsenal
# Eddie Nketiah  -  FW -  https://fbref.com/en/players/a53649b7/Eddie-Nketiah  -  Arsenal
# Salah Oulad M'Hand  -  MF -  https://fbref.com/en/players/b85c3273/Salah-Oulad-MHand  -  Arsenal
# Aaron Ramsdale  -  GK -  https://fbref.com/en/players/466fb2c5/Aaron-Ramsdale  -  Arsenal
# Tommy Setford  -  GK -  https://fbref.com/en/players/d1a2e006/Tommy-Setford  -  Arsenal
# Scraping players from Manchester City...
# Ederson  -  GK -  https://fbref.com/en/players/3bb7b8b4/Ederson  -  Manchester City
# Erling Haaland  -  FW -  https://fbref.com/en/players/1f44ac21/Erling-Haaland  -  Manchester City
# Manuel Akanji  -  DF -  https://fbref.com/en/players/89ac64a6/Manuel-Akanji  -  Manchester City
# Joško Gvardiol  -  DF -  https://fbref.com/en/players/5ad50391/Josko-Gvardiol  -  Manchester City
# Rúben Dias  -  DF -  https://fbref.com/en/players/31c69ef1/Ruben-Dias  -  Manchester City
# Bernardo Silva  -  MF,FW -  https://fbref.com/en/players/3eb22ec9/Bernardo-Silva  -  Manchester City
# Mateo Kovačić  -  MF -  https://fbref.com/en/players/79c0821a/Mateo-Kovacic  -  Manchester City
# Rico Lewis  -  MF,DF -  https://fbref.com/en/players/b57e066e/Rico-Lewis  -  Manchester City
# İlkay Gündoğan  -  MF -  https://fbref.com/en/players/819b3158/Ilkay-Gundogan  -  Manchester City
# Kevin De Bruyne  -  MF -  https://fbref.com/en/players/e46012d4/Kevin-De-Bruyne  -  Manchester City
# Jeremy Doku  -  FW -  https://fbref.com/en/players/fffea3e5/Jeremy-Doku  -  Manchester City
# Jack Grealish  -  FW,MF -  https://fbref.com/en/players/b0b4fd3e/Jack-Grealish  -  Manchester City
# Sávio  -  FW -  https://fbref.com/en/players/fe6e7156/Savio  -  Manchester City
# Kyle Walker  -  DF -  https://fbref.com/en/players/86dd77d1/Kyle-Walker  -  Manchester City
# Phil Foden  -  MF,FW -  https://fbref.com/en/players/ed1e53f3/Phil-Foden  -  Manchester City
# John Stones  -  DF,MF -  https://fbref.com/en/players/5eecec3d/John-Stones  -  Manchester City
# Rodri  -  MF -  https://fbref.com/en/players/6434f10d/Rodri  -  Manchester City
# Matheus Nunes  -  FW,MF -  https://fbref.com/en/players/e6af02e0/Matheus-Nunes  -  Manchester City
# Nathan Aké  -  DF -  https://fbref.com/en/players/eaeca114/Nathan-Ake  -  Manchester City
# James Mcatee  -  FW -  https://fbref.com/en/players/96593e89/James-Mcatee  -  Manchester City
# Scott Carson  -  GK -  https://fbref.com/en/players/3e1550ee/Scott-Carson  -  Manchester City
# Issa Kaboré  -  DF,MF -  https://fbref.com/en/players/c066d1a5/Issa-Kabore  -  Manchester City
# Stefan Ortega  -  GK -  https://fbref.com/en/players/c1242d4e/Stefan-Ortega  -  Manchester City
# Nico O’Reilly  -  FW -  https://fbref.com/en/players/91ca4a16/Nico-OReilly  -  Manchester City
# Scraping players from Eint Frankfurt...
# Robin Koch  -  DF -  https://fbref.com/en/players/ea6bc03a/Robin-Koch  -  Eint Frankfurt
# Rasmus Kristensen  -  DF,MF -  https://fbref.com/en/players/39769cff/Rasmus-Kristensen  -  Eint Frankfurt
# Tuta  -  DF,MF -  https://fbref.com/en/players/35d64857/Tuta  -  Eint Frankfurt
# Arthur Theate  -  DF -  https://fbref.com/en/players/df8d6029/Arthur-Theate  -  Eint Frankfurt
# Hugo Larsson  -  MF -  https://fbref.com/en/players/00c9a283/Hugo-Larsson  -  Eint Frankfurt
# Omar Marmoush  -  FW,MF -  https://fbref.com/en/players/0e0102eb/Omar-Marmoush  -  Eint Frankfurt
# Ellyes Skhiri  -  MF -  https://fbref.com/en/players/c2211709/Ellyes-Skhiri  -  Eint Frankfurt
# Hugo Ekitike  -  FW -  https://fbref.com/en/players/5b92d896/Hugo-Ekitike  -  Eint Frankfurt
# Fares Chaïbi  -  MF,FW -  https://fbref.com/en/players/357103bd/Fares-Chaibi  -  Eint Frankfurt
# Kauã Santos  -  GK -  https://fbref.com/en/players/c7c50cb5/Kaua-Santos  -  Eint Frankfurt
# Mario Götze  -  FW,MF -  https://fbref.com/en/players/9efa1d25/Mario-Gotze  -  Eint Frankfurt
# Kevin Trapp  -  GK -  https://fbref.com/en/players/ce17b5eb/Kevin-Trapp  -  Eint Frankfurt
# Ansgar Knauff  -  MF -  https://fbref.com/en/players/19a967ab/Ansgar-Knauff  -  Eint Frankfurt
# Niels Nkounkou  -  MF,DF -  https://fbref.com/en/players/f5b281e7/Niels-Nkounkou  -  Eint Frankfurt
# Igor Matanovic  -  FW -  https://fbref.com/en/players/948e1292/Igor-Matanovic  -  Eint Frankfurt
# Junior Dina Ebimbe  -  FW,MF -  https://fbref.com/en/players/95bb6ddc/Junior-Dina-Ebimbe  -  Eint Frankfurt
# Aurele Amenda  -  DF -  https://fbref.com/en/players/1227a22d/Aurele-Amenda  -  Eint Frankfurt
# Mahmoud Dahoud  -  MF -  https://fbref.com/en/players/db4ed67b/Mahmoud-Dahoud  -  Eint Frankfurt
# Can Uzun  -  FW,MF -  https://fbref.com/en/players/1d0b134a/Can-Uzun  -  Eint Frankfurt
# Jean Mattéo Bahoya  -  MF -  https://fbref.com/en/players/70d4c949/Jean-Matteo-Bahoya  -  Eint Frankfurt
# Oscar Højlund  -  MF -  https://fbref.com/en/players/3e2bbae6/Oscar-Hojlund  -  Eint Frankfurt
# Nnamdi Collins  -  DF -  https://fbref.com/en/players/8eb5c94c/Nnamdi-Collins  -  Eint Frankfurt
# Nathaniel Brown  -  DF -  https://fbref.com/en/players/abc79c47/Nathaniel-Brown  -  Eint Frankfurt
# Timothy Chandler  -  DF,MF -  https://fbref.com/en/players/b3b7f5a6/Timothy-Chandler  -  Eint Frankfurt
# Jens Grahl  -  GK -  https://fbref.com/en/players/f26dee6b/Jens-Grahl  -  Eint Frankfurt
# Scraping players from Real Madrid...
# Federico Valverde  -  MF -  https://fbref.com/en/players/0959c2a2/Federico-Valverde  -  Real Madrid
# Éder Militão  -  DF -  https://fbref.com/en/players/2784f898/Eder-Militao  -  Real Madrid
# Antonio Rüdiger  -  DF -  https://fbref.com/en/players/18b896d6/Antonio-Rudiger  -  Real Madrid
# Vinicius Júnior  -  FW -  https://fbref.com/en/players/7111d552/Vinicius-Junior  -  Real Madrid
# Thibaut Courtois  -  GK -  https://fbref.com/en/players/1840e36d/Thibaut-Courtois  -  Real Madrid
# Aurélien Tchouaméni  -  MF,DF -  https://fbref.com/en/players/4f255115/Aurelien-Tchouameni  -  Real Madrid
# Kylian Mbappé  -  FW -  https://fbref.com/en/players/42fd9c7f/Kylian-Mbappe  -  Real Madrid
# Dani Carvajal  -  DF -  https://fbref.com/en/players/4958bfb2/Dani-Carvajal  -  Real Madrid
# Ferland Mendy  -  DF -  https://fbref.com/en/players/3cefcaef/Ferland-Mendy  -  Real Madrid
# Rodrygo  -  FW -  https://fbref.com/en/players/8f5e92a6/Rodrygo  -  Real Madrid
# Luka Modrić  -  MF -  https://fbref.com/en/players/6025fab1/Luka-Modric  -  Real Madrid
# Jude Bellingham  -  MF -  https://fbref.com/en/players/57d88cf9/Jude-Bellingham  -  Real Madrid
# Arda Güler  -  MF,FW -  https://fbref.com/en/players/3741ca58/Arda-Guler  -  Real Madrid
# Fran Garcia  -  DF -  https://fbref.com/en/players/7226539b/Fran-Garcia  -  Real Madrid
# Lucas Vázquez  -  DF -  https://fbref.com/en/players/fd51b456/Lucas-Vazquez  -  Real Madrid
# Brahim Díaz  -  FW,MF -  https://fbref.com/en/players/407feb71/Brahim-Diaz  -  Real Madrid
# Andriy Lunin  -  GK -  https://fbref.com/en/players/3061e1ec/Andriy-Lunin  -  Real Madrid
# Eduardo Camavinga  -  MF -  https://fbref.com/en/players/7b9c2d84/Eduardo-Camavinga  -  Real Madrid
# Dani Ceballos  -  MF -  https://fbref.com/en/players/c0617e2b/Dani-Ceballos  -  Real Madrid
# Endrick  -  FW -  https://fbref.com/en/players/a2728fbf/Endrick  -  Real Madrid
# Jesús Vallejo  -  DF -  https://fbref.com/en/players/c2111b45/Jesus-Vallejo  -  Real Madrid
# Chema  -  MF -  https://fbref.com/en/players/39ef21fa/Chema  -  Real Madrid
# Fran  -  GK -  https://fbref.com/en/players/5e550a91/Fran  -  Real Madrid
# David Jiménez  -  DF -  https://fbref.com/en/players/aa2aab45/David-Jimenez  -  Real Madrid
# Sergio Mestre  -  GK -  https://fbref.com/en/players/b2cd9dff/Sergio-Mestre  -  Real Madrid
# Jacobo Ramón  -  DF -  https://fbref.com/en/players/4772b1d1/Jacobo-Ramon  -  Real Madrid
# Scraping players from Napoli...
# Giovanni Di Lorenzo  -  DF -  https://fbref.com/en/players/230a2fac/Giovanni-Di-Lorenzo  -  Napoli
# Amir Rrahmani  -  DF -  https://fbref.com/en/players/4b3e1a38/Amir-Rrahmani  -  Napoli
# Andre-Frank Zambo Anguissa  -  MF -  https://fbref.com/en/players/6bb2c084/Andre-Frank-Zambo-Anguissa  -  Napoli
# Stanislav Lobotka  -  MF -  https://fbref.com/en/players/e1cbb531/Stanislav-Lobotka  -  Napoli
# Matteo Politano  -  MF,FW -  https://fbref.com/en/players/5e861944/Matteo-Politano  -  Napoli
# Khvicha Kvaratskhelia  -  MF,FW -  https://fbref.com/en/players/dea88efd/Khvicha-Kvaratskhelia  -  Napoli
# Alessandro Buongiorno  -  DF -  https://fbref.com/en/players/4ae67f27/Alessandro-Buongiorno  -  Napoli
# Mathías Olivera  -  DF -  https://fbref.com/en/players/41c12f75/Mathias-Olivera  -  Napoli
# Alex Meret  -  GK -  https://fbref.com/en/players/9413b19f/Alex-Meret  -  Napoli
# Pasquale Mazzocchi  -  DF -  https://fbref.com/en/players/eb0ec070/Pasquale-Mazzocchi  -  Napoli
# Romelu Lukaku  -  FW -  https://fbref.com/en/players/5eae500a/Romelu-Lukaku  -  Napoli
# Scott McTominay  -  MF -  https://fbref.com/en/players/d93c2511/Scott-McTominay  -  Napoli
# Elia Caprile  -  GK -  https://fbref.com/en/players/97d7afbd/Elia-Caprile  -  Napoli
# Giacomo Raspadori  -  FW,MF -  https://fbref.com/en/players/6e058f06/Giacomo-Raspadori  -  Napoli
# Leonardo Spinazzola  -  DF -  https://fbref.com/en/players/3626daea/Leonardo-Spinazzola  -  Napoli
# Giovanni Simeone  -  FW -  https://fbref.com/en/players/343c0d52/Giovanni-Simeone  -  Napoli
# Juan Jesus  -  DF -  https://fbref.com/en/players/79083382/Juan-Jesus  -  Napoli
# David Neres  -  MF,FW -  https://fbref.com/en/players/4f1e6a0b/David-Neres  -  Napoli
# Billy Gilmour  -  MF -  https://fbref.com/en/players/df10e27c/Billy-Gilmour  -  Napoli
# Michael Folorunsho  -  FW -  https://fbref.com/en/players/c391a179/Michael-Folorunsho  -  Napoli
# Walid Cheddira  -  FW -  https://fbref.com/en/players/0545a08e/Walid-Cheddira  -  Napoli
# Cyril Ngonge  -  DF -  https://fbref.com/en/players/2b8360f1/Cyril-Ngonge  -  Napoli
# Nikita Contini Baranovsky  -  GK -  https://fbref.com/en/players/e95069bb/Nikita-Contini-Baranovsky  -  Napoli
# Gianluca Gaetano  -  FW,MF -  https://fbref.com/en/players/3b387cc7/Gianluca-Gaetano  -  Napoli
# Gennaro Iaccarino  -  MF -  https://fbref.com/en/players/5b079870/Gennaro-Iaccarino  -  Napoli
# Rafa Marín  -  DF -  https://fbref.com/en/players/3239a8ed/Rafa-Marin  -  Napoli
# Francesco Mezzoni  -  FW -  https://fbref.com/en/players/bb0b6521/Francesco-Mezzoni  -  Napoli
# Coli Saco  -  MF -  https://fbref.com/en/players/95df20b2/Coli-Saco  -  Napoli
# Claudio Turi  -  GK -  https://fbref.com/en/players/193a5d9c/Claudio-Turi  -  Napoli
# Alessio Zerbin  -  FW -  https://fbref.com/en/players/d19ef4ef/Alessio-Zerbin  -  Napoli
# Scraping players from RB Leipzig...
# Péter Gulácsi  -  GK -  https://fbref.com/en/players/bcb2ccd8/Peter-Gulacsi  -  RB Leipzig
# Xavi Simons  -  MF -  https://fbref.com/en/players/da4d670f/Xavi-Simons  -  RB Leipzig
# David Raum  -  DF -  https://fbref.com/en/players/7d450ed3/David-Raum  -  RB Leipzig
# Benjamin Šeško  -  FW,MF -  https://fbref.com/en/players/3260690c/Benjamin-Sesko  -  RB Leipzig
# Amadou Haidara  -  MF -  https://fbref.com/en/players/92432bc6/Amadou-Haidara  -  RB Leipzig
# Loïs Openda  -  FW -  https://fbref.com/en/players/8652a85c/Lois-Openda  -  RB Leipzig
# Castello Lukeba  -  DF -  https://fbref.com/en/players/5b9512c5/Castello-Lukeba  -  RB Leipzig
# Lukas Klostermann  -  DF -  https://fbref.com/en/players/ca8033cb/Lukas-Klostermann  -  RB Leipzig
# Willi Orban  -  DF -  https://fbref.com/en/players/20030c06/Willi-Orban  -  RB Leipzig
# Nicolas Seiwald  -  MF -  https://fbref.com/en/players/28c6e925/Nicolas-Seiwald  -  RB Leipzig
# Lutsharel Geertruida  -  DF -  https://fbref.com/en/players/242e1043/Lutsharel-Geertruida  -  RB Leipzig
# Kevin Kampl  -  MF -  https://fbref.com/en/players/b825a650/Kevin-Kampl  -  RB Leipzig
# Antonio Nusa  -  MF -  https://fbref.com/en/players/4ab12002/Antonio-Nusa  -  RB Leipzig
# Benjamin Henrichs  -  DF -  https://fbref.com/en/players/0a89e877/Benjamin-Henrichs  -  RB Leipzig
# Arthur Vermeeren  -  MF -  https://fbref.com/en/players/722494dc/Arthur-Vermeeren  -  RB Leipzig
# Christoph Baumgartner  -  MF,DF -  https://fbref.com/en/players/437f2b00/Christoph-Baumgartner  -  RB Leipzig
# Yussuf Poulsen  -  FW -  https://fbref.com/en/players/d2416c2e/Yussuf-Poulsen  -  RB Leipzig
# El Chadaille Bitshiabu  -  DF -  https://fbref.com/en/players/2180c761/El-Chadaille-Bitshiabu  -  RB Leipzig
# Mohamed Simakan  -  DF -  https://fbref.com/en/players/fcb27134/Mohamed-Simakan  -  RB Leipzig
# André Silva  -  FW -  https://fbref.com/en/players/3effaa34/Andre-Silva  -  RB Leipzig
# Elif Elmas  -  FW,MF -  https://fbref.com/en/players/cf007308/Elif-Elmas  -  RB Leipzig
# Viggo Gebel  -  MF -  https://fbref.com/en/players/92ed2acc/Viggo-Gebel  -  RB Leipzig
# Maarten Vandevoordt  -  GK -  https://fbref.com/en/players/f9e0c603/Maarten-Vandevoordt  -  RB Leipzig
# Scraping players from Chelsea...
# Robert Sánchez  -  GK -  https://fbref.com/en/players/6a713852/Robert-Sanchez  -  Chelsea
# Levi Colwill  -  DF -  https://fbref.com/en/players/700783e7/Levi-Colwill  -  Chelsea
# Moisés Caicedo  -  MF -  https://fbref.com/en/players/16264a81/Moises-Caicedo  -  Chelsea
# Wesley Fofana  -  DF -  https://fbref.com/en/players/132a82f1/Wesley-Fofana  -  Chelsea
# Cole Palmer  -  MF,FW -  https://fbref.com/en/players/dc7f8a28/Cole-Palmer  -  Chelsea
# Marc Cucurella  -  DF -  https://fbref.com/en/players/1daec722/Marc-Cucurella  -  Chelsea
# Nicolas Jackson  -  FW -  https://fbref.com/en/players/9c36ed83/Nicolas-Jackson  -  Chelsea
# Enzo Fernández  -  MF -  https://fbref.com/en/players/5ff4ab71/Enzo-Fernandez  -  Chelsea
# Noni Madueke  -  FW -  https://fbref.com/en/players/bf34eebd/Noni-Madueke  -  Chelsea
# Malo Gusto  -  DF -  https://fbref.com/en/players/d56b9520/Malo-Gusto  -  Chelsea
# Jadon Sancho  -  FW -  https://fbref.com/en/players/dbf053da/Jadon-Sancho  -  Chelsea
# Pedro Neto  -  FW -  https://fbref.com/en/players/7ba2eaa9/Pedro-Neto  -  Chelsea
# Christopher Nkunku  -  FW -  https://fbref.com/en/players/7c56da38/Christopher-Nkunku  -  Chelsea
# Renato Veiga  -  MF,DF -  https://fbref.com/en/players/fc8fcbd1/Renato-Veiga  -  Chelsea
# Tosin Adarabioyo  -  DF -  https://fbref.com/en/players/c81d773d/Tosin-Adarabioyo  -  Chelsea
# Axel Disasi  -  DF -  https://fbref.com/en/players/ad82197c/Axel-Disasi  -  Chelsea
# Mykhailo Mudryk  -  FW -  https://fbref.com/en/players/049a888d/Mykhailo-Mudryk  -  Chelsea
# Roméo Lavia  -  MF -  https://fbref.com/en/players/ecad9aa5/Romeo-Lavia  -  Chelsea
# João Félix  -  MF,FW -  https://fbref.com/en/players/8aafd64f/Joao-Felix  -  Chelsea
# Kiernan Dewsbury-Hall  -  MF -  https://fbref.com/en/players/5c74c0f5/Kiernan-Dewsbury-Hall  -  Chelsea
# Marc Guiu  -  FW -  https://fbref.com/en/players/d3d774cc/Marc-Guiu  -  Chelsea
# Benoît Badiashile  -  DF -  https://fbref.com/en/players/06df8256/Benoit-Badiashile  -  Chelsea
# Cesare Casadei  -  MF -  https://fbref.com/en/players/fb920f3a/Cesare-Casadei  -  Chelsea
# Filip Jørgensen  -  GK -  https://fbref.com/en/players/0107757e/Filip-Jorgensen  -  Chelsea
# Scraping players from Aston Villa...
# Emiliano Martínez  -  GK -  https://fbref.com/en/players/7956236f/Emiliano-Martinez  -  Aston Villa
# Pau Torres  -  DF -  https://fbref.com/en/players/532e1e4f/Pau-Torres  -  Aston Villa
# Youri Tielemans  -  MF -  https://fbref.com/en/players/56f7a928/Youri-Tielemans  -  Aston Villa
# Morgan Rogers  -  MF,FW -  https://fbref.com/en/players/2e5915f1/Morgan-Rogers  -  Aston Villa
# Ezri Konsa  -  DF -  https://fbref.com/en/players/0313a347/Ezri-Konsa  -  Aston Villa
# Ollie Watkins  -  FW -  https://fbref.com/en/players/aed3a70f/Ollie-Watkins  -  Aston Villa
# Lucas Digne  -  DF -  https://fbref.com/en/players/1b84dbe1/Lucas-Digne  -  Aston Villa
# Amadou Onana  -  MF -  https://fbref.com/en/players/828657ff/Amadou-Onana  -  Aston Villa
# John McGinn  -  FW,MF -  https://fbref.com/en/players/90f91999/John-McGinn  -  Aston Villa
# Leon Bailey  -  FW,MF -  https://fbref.com/en/players/3a233281/Leon-Bailey  -  Aston Villa
# Jacob Ramsey  -  FW,MF -  https://fbref.com/en/players/1544f145/Jacob-Ramsey  -  Aston Villa
# Matty Cash  -  DF -  https://fbref.com/en/players/2389cdc2/Matty-Cash  -  Aston Villa
# Diego Carlos  -  DF -  https://fbref.com/en/players/b4a014b1/Diego-Carlos  -  Aston Villa
# Lamare Bogarde  -  DF -  https://fbref.com/en/players/bca5c4a7/Lamare-Bogarde  -  Aston Villa
# Ross Barkley  -  MF -  https://fbref.com/en/players/3a24769f/Ross-Barkley  -  Aston Villa
# Jaden Philogene Bidace  -  FW,MF -  https://fbref.com/en/players/19f4d211/Jaden-Philogene-Bidace  -  Aston Villa
# Jhon Durán  -  FW -  https://fbref.com/en/players/414184f7/Jhon-Duran  -  Aston Villa
# Ian Maatsen  -  DF,MF -  https://fbref.com/en/players/cab9634e/Ian-Maatsen  -  Aston Villa
# Kosta Nedeljković  -  DF -  https://fbref.com/en/players/c70be9cf/Kosta-Nedeljkovic  -  Aston Villa
# Emi Buendía  -  MF,FW -  https://fbref.com/en/players/66b76d44/Emi-Buendia  -  Aston Villa
# Joe Gauci  -  GK -  https://fbref.com/en/players/5600c774/Joe-Gauci  -  Aston Villa
# Sil Swinkels  -  DF -  https://fbref.com/en/players/a42f6058/Sil-Swinkels  -  Aston Villa
# Kadan Young  -  MF -  https://fbref.com/en/players/91c75917/Kadan-Young  -  Aston Villa
# Oliwier Zych  -  GK -  https://fbref.com/en/players/be18d79f/Oliwier-Zych  -  Aston Villa
# Scraping players from Juventus...
# Dušan Vlahović  -  FW -  https://fbref.com/en/players/79443529/Dusan-Vlahovic  -  Juventus
# Andrea Cambiaso  -  DF,FW -  https://fbref.com/en/players/247ed022/Andrea-Cambiaso  -  Juventus
# Gleison Bremer  -  DF -  https://fbref.com/en/players/5fd5ed86/Gleison-Bremer  -  Juventus
# Kenan Yıldız  -  FW,MF -  https://fbref.com/en/players/d8cda243/Kenan-Yildiz  -  Juventus
# Manuel Locatelli  -  MF -  https://fbref.com/en/players/a8a874f1/Manuel-Locatelli  -  Juventus
# Michele Di Gregorio  -  GK -  https://fbref.com/en/players/4e0c8d66/Michele-Di-Gregorio  -  Juventus
# Federico Gatti  -  DF -  https://fbref.com/en/players/18dd3219/Federico-Gatti  -  Juventus
# Nicolò Savona  -  DF -  https://fbref.com/en/players/e041497d/Nicolo-Savona  -  Juventus
# Teun Koopmeiners  -  MF -  https://fbref.com/en/players/a26fb8aa/Teun-Koopmeiners  -  Juventus
# Pierre Kalulu  -  DF -  https://fbref.com/en/players/85f7d1be/Pierre-Kalulu  -  Juventus
# Samuel Mbangula  -  FW -  https://fbref.com/en/players/3e25e70c/Samuel-Mbangula  -  Juventus
# Nicolò Fagioli  -  MF -  https://fbref.com/en/players/366be751/Nicolo-Fagioli  -  Juventus
# Nicolás González  -  FW -  https://fbref.com/en/players/2374aaca/Nicolas-Gonzalez  -  Juventus
# Juan David Cabal  -  DF -  https://fbref.com/en/players/ef6eef89/Juan-David-Cabal  -  Juventus
# Weston McKennie  -  MF -  https://fbref.com/en/players/01c3aff5/Weston-McKennie  -  Juventus
# Mattia Perin  -  GK -  https://fbref.com/en/players/4c62d0c8/Mattia-Perin  -  Juventus
# Khéphren Thuram  -  MF -  https://fbref.com/en/players/7d9397f8/Khephren-Thuram  -  Juventus
# Douglas Luiz  -  MF -  https://fbref.com/en/players/6f7d826d/Douglas-Luiz  -  Juventus
# Francisco Conceição  -  FW -  https://fbref.com/en/players/5ef3d210/Francisco-Conceicao  -  Juventus
# Danilo  -  DF -  https://fbref.com/en/players/94b2001f/Danilo  -  Juventus
# Timothy Weah  -  FW -  https://fbref.com/en/players/8eec784d/Timothy-Weah  -  Juventus
# Jonas Rouhi  -  DF -  https://fbref.com/en/players/31908a0a/Jonas-Rouhi  -  Juventus
# Lorenzo Anghelè  -  FW -  https://fbref.com/en/players/b2f3d550/Lorenzo-Anghele  -  Juventus
# Vasilije Adžić  -  MF -  https://fbref.com/en/players/8b0f9fb8/Vasilije-Adzic  -  Juventus
# Carlo Pinsoglio  -  GK -  https://fbref.com/en/players/f6a06749/Carlo-Pinsoglio  -  Juventus
# Scraping players from Marseille...
# Gerónimo Rulli  -  GK -  https://fbref.com/en/players/625c144a/Geronimo-Rulli  -  Marseille
# Michael Amir Murillo  -  DF -  https://fbref.com/en/players/349cae8f/Michael-Amir-Murillo  -  Marseille
# Pierre Højbjerg  -  MF,DF -  https://fbref.com/en/players/8b04d6c1/Pierre-Hojbjerg  -  Marseille
# Mason Greenwood  -  FW -  https://fbref.com/en/players/58eee997/Mason-Greenwood  -  Marseille
# Luis Henrique  -  FW -  https://fbref.com/en/players/f36d5624/Luis-Henrique  -  Marseille
# Geoffrey Kondogbia  -  MF,DF -  https://fbref.com/en/players/cce181df/Geoffrey-Kondogbia  -  Marseille
# Amine Harit  -  MF -  https://fbref.com/en/players/e7d59f4f/Amine-Harit  -  Marseille
# Lilian Brassier  -  DF -  https://fbref.com/en/players/5b146df3/Lilian-Brassier  -  Marseille
# Derek Cornelius  -  DF -  https://fbref.com/en/players/577744b8/Derek-Cornelius  -  Marseille
# Elye Wahi  -  FW -  https://fbref.com/en/players/0d7b6576/Elye-Wahi  -  Marseille
# Leonardo Balerdi  -  DF -  https://fbref.com/en/players/7c3ed041/Leonardo-Balerdi  -  Marseille
# Quentin Merlin  -  DF,MF -  https://fbref.com/en/players/0bfca6a1/Quentin-Merlin  -  Marseille
# Neal Maupay  -  FW -  https://fbref.com/en/players/4bcf39f6/Neal-Maupay  -  Marseille
# Ismaël Koné  -  MF -  https://fbref.com/en/players/e0220b70/Ismael-Kone  -  Marseille
# Valentin Rongier  -  DF,MF -  https://fbref.com/en/players/ed45c4a5/Valentin-Rongier  -  Marseille
# Pol Lirola  -  DF,FW -  https://fbref.com/en/players/ff800ed8/Pol-Lirola  -  Marseille
# Ulisses Garcia  -  DF,MF -  https://fbref.com/en/players/c952f633/Ulisses-Garcia  -  Marseille
# Valentin Carboni  -  MF,FW -  https://fbref.com/en/players/707b98f1/Valentin-Carboni  -  Marseille
# Jon Rowe  -  FW,MF -  https://fbref.com/en/players/8c12f884/Jon-Rowe  -  Marseille
# Adrien Rabiot  -  MF,DF -  https://fbref.com/en/players/8794e251/Adrien-Rabiot  -  Marseille
# Bamo Meïté  -  DF,MF -  https://fbref.com/en/players/04ac78d2/Bamo-Meite  -  Marseille
# Enzo Sternal  -  FW -  https://fbref.com/en/players/c2e3ceb7/Enzo-Sternal  -  Marseille
# Faris Pemi Moumbagna  -  FW -  https://fbref.com/en/players/58aae0a9/Faris-Pemi-Moumbagna  -  Marseille
# Keyliane Abdallah  -  FW -  https://fbref.com/en/players/7310786d/Keyliane-Abdallah  -  Marseille
# Darryl Bakola  -  MF -  https://fbref.com/en/players/57de24a3/Darryl-Bakola  -  Marseille
# Salim Ben Seghir  -  FW -  https://fbref.com/en/players/1f6298f2/Salim-Ben-Seghir  -  Marseille
# Jeffrey De Lange  -  GK -  https://fbref.com/en/players/c31cf14b/Jeffrey-De-Lange  -  Marseille
# Emmanuel Koum Mbondo  -  FW -  https://fbref.com/en/players/cb3c6ca9/Emmanuel-Koum-Mbondo  -  Marseille
# Gael Lafont  -  FW -  https://fbref.com/en/players/4f5a4218/Gael-Lafont  -  Marseille
# Roggerio Nyakossi  -  DF -  https://fbref.com/en/players/2e64644b/Roggerio-Nyakossi  -  Marseille
# Scraping players from Atlético Madrid...
# Jan Oblak  -  GK -  https://fbref.com/en/players/ee8508c0/Jan-Oblak  -  Atlético Madrid
# Antoine Griezmann  -  FW,MF -  https://fbref.com/en/players/df69b544/Antoine-Griezmann  -  Atlético Madrid
# Koke  -  MF -  https://fbref.com/en/players/55126f3b/Koke  -  Atlético Madrid
# Robin Le Normand  -  DF -  https://fbref.com/en/players/9a64e67e/Robin-Le-Normand  -  Atlético Madrid
# Marcos Llorente  -  DF,MF -  https://fbref.com/en/players/02c15616/Marcos-Llorente  -  Atlético Madrid
# José María Giménez  -  DF -  https://fbref.com/en/players/f0da930c/Jose-Maria-Gimenez  -  Atlético Madrid
# Julián Álvarez  -  FW,MF -  https://fbref.com/en/players/15ab5a2b/Julian-Alvarez  -  Atlético Madrid
# Conor Gallagher  -  MF -  https://fbref.com/en/players/c2731c10/Conor-Gallagher  -  Atlético Madrid
# Alexander Sørloth  -  FW -  https://fbref.com/en/players/e92cd3f7/Alexander-Sorloth  -  Atlético Madrid
# Samuel Lino  -  DF,MF -  https://fbref.com/en/players/2a295d33/Samuel-Lino  -  Atlético Madrid
# Reinildo Mandava  -  DF -  https://fbref.com/en/players/c20bdcd7/Reinildo-Mandava  -  Atlético Madrid
# César Azpilicueta  -  DF -  https://fbref.com/en/players/53cad200/Cesar-Azpilicueta  -  Atlético Madrid
# Nahuel Molina  -  DF -  https://fbref.com/en/players/23610943/Nahuel-Molina  -  Atlético Madrid
# Pablo Barrios  -  MF -  https://fbref.com/en/players/45736cec/Pablo-Barrios  -  Atlético Madrid
# Rodrigo De Paul  -  MF -  https://fbref.com/en/players/162efffd/Rodrigo-De-Paul  -  Atlético Madrid
# Axel Witsel  -  DF -  https://fbref.com/en/players/5dfc6ad5/Axel-Witsel  -  Atlético Madrid
# Rodrigo Riquelme  -  DF,MF -  https://fbref.com/en/players/65154df0/Rodrigo-Riquelme  -  Atlético Madrid
# Javi Galán  -  DF -  https://fbref.com/en/players/a4b00319/Javi-Galan  -  Atlético Madrid
# Giuliano Simeone  -  MF,DF -  https://fbref.com/en/players/a6536561/Giuliano-Simeone  -  Atlético Madrid
# Clément Lenglet  -  DF -  https://fbref.com/en/players/4f28a6ff/Clement-Lenglet  -  Atlético Madrid
# Juan Musso  -  GK -  https://fbref.com/en/players/a111cf41/Juan-Musso  -  Atlético Madrid
# Ángel Correa  -  FW,MF -  https://fbref.com/en/players/01eb744d/Angel-Correa  -  Atlético Madrid
# Antonio Gomis  -  GK -  https://fbref.com/en/players/f0f4671c/Antonio-Gomis  -  Atlético Madrid
# Alejandro Iturbe  -  GK -  https://fbref.com/en/players/d58f4c7a/Alejandro-Iturbe  -  Atlético Madrid
# Ilias Kostis  -  DF -  https://fbref.com/en/players/9b94c838/Ilias-Kostis  -  Atlético Madrid
# Thomas Lemar  -  MF -  https://fbref.com/en/players/4dbd0916/Thomas-Lemar  -  Atlético Madrid
# Horaţiu Moldovan  -  GK -  https://fbref.com/en/players/771ded26/Horatiu-Moldovan  -  Atlético Madrid
# Javier Serrano  -  MF -  https://fbref.com/en/players/0a8fd9cb/Javier-Serrano  -  Atlético Madrid
# Arthur Vermeeren  -  MF -  https://fbref.com/en/players/722494dc/Arthur-Vermeeren  -  Atlético Madrid
# Scraping players from Inter...
# Yann Sommer  -  GK -  https://fbref.com/en/players/420c18a1/Yann-Sommer  -  Inter
# Federico Dimarco  -  DF -  https://fbref.com/en/players/970b8574/Federico-Dimarco  -  Inter
# Marcus Thuram  -  FW -  https://fbref.com/en/players/6f8cd6d0/Marcus-Thuram  -  Inter
# Henrikh Mkhitaryan  -  MF -  https://fbref.com/en/players/dd0daf32/Henrikh-Mkhitaryan  -  Inter
# Francesco Acerbi  -  DF -  https://fbref.com/en/players/b96b595c/Francesco-Acerbi  -  Inter
# Lautaro Martínez  -  FW -  https://fbref.com/en/players/f7036e1c/Lautaro-Martinez  -  Inter
# Alessandro Bastoni  -  DF -  https://fbref.com/en/players/75b86fb3/Alessandro-Bastoni  -  Inter
# Matteo Darmian  -  DF -  https://fbref.com/en/players/96e0490d/Matteo-Darmian  -  Inter
# Hakan Çalhanoğlu  -  MF -  https://fbref.com/en/players/cd0fa27b/Hakan-Calhanoglu  -  Inter
# Benjamin Pavard  -  DF -  https://fbref.com/en/players/45a03961/Benjamin-Pavard  -  Inter
# Nicolò Barella  -  MF -  https://fbref.com/en/players/6928979a/Nicolo-Barella  -  Inter
# Davide Frattesi  -  MF -  https://fbref.com/en/players/2a7d27c1/Davide-Frattesi  -  Inter
# Yann Aurel Bisseck  -  DF -  https://fbref.com/en/players/3963c25b/Yann-Aurel-Bisseck  -  Inter
# Mehdi Taremi  -  FW -  https://fbref.com/en/players/4c2a5d34/Mehdi-Taremi  -  Inter
# Carlos Augusto  -  DF -  https://fbref.com/en/players/8d3cd59d/Carlos-Augusto  -  Inter
# Denzel Dumfries  -  DF -  https://fbref.com/en/players/481c9ece/Denzel-Dumfries  -  Inter
# Kristjan Asllani  -  MF -  https://fbref.com/en/players/0fdcef0e/Kristjan-Asllani  -  Inter
# Stefan de Vrij  -  DF -  https://fbref.com/en/players/d0d8dd44/Stefan-de-Vrij  -  Inter
# Piotr Zieliński  -  MF -  https://fbref.com/en/players/a5296e55/Piotr-Zielinski  -  Inter
# Marko Arnautović  -  FW -  https://fbref.com/en/players/00459419/Marko-Arnautovic  -  Inter
# Joaquín Correa  -  MF,FW -  https://fbref.com/en/players/45b9b619/Joaquin-Correa  -  Inter
# Raffaele Di Gennaro  -  GK -  https://fbref.com/en/players/7a4050d5/Raffaele-Di-Gennaro  -  Inter
# Alessandro Fontanarosa  -  DF -  https://fbref.com/en/players/8961065a/Alessandro-Fontanarosa  -  Inter
# Josep Martinez  -  GK -  https://fbref.com/en/players/11d8aff0/Josep-Martinez  -  Inter
# Tiago Palacios  -  DF -  https://fbref.com/en/players/404101f9/Tiago-Palacios  -  Inter
# Scraping players from Freiburg...
# Christian Günter  -  DF -  https://fbref.com/en/players/8593f88c/Christian-Gunter  -  Freiburg
# Maximilian Eggestein  -  MF -  https://fbref.com/en/players/beb882a8/Maximilian-Eggestein  -  Freiburg
# Ritsu Doan  -  FW -  https://fbref.com/en/players/d01bbb6f/Ritsu-Doan  -  Freiburg
# Junior Adamu  -  FW -  https://fbref.com/en/players/82e12fe7/Junior-Adamu  -  Freiburg
# Philipp Lienhart  -  DF -  https://fbref.com/en/players/302527b2/Philipp-Lienhart  -  Freiburg
# Vincenzo Grifo  -  FW,MF -  https://fbref.com/en/players/54e4866f/Vincenzo-Grifo  -  Freiburg
# Lukas Kübler  -  DF -  https://fbref.com/en/players/2a29eb9b/Lukas-Kubler  -  Freiburg
# Patrick Osterhage  -  MF -  https://fbref.com/en/players/9662c9ec/Patrick-Osterhage  -  Freiburg
# Noah Atubolu  -  GK -  https://fbref.com/en/players/dbd1b101/Noah-Atubolu  -  Freiburg
# Matthias Ginter  -  DF -  https://fbref.com/en/players/f521b80a/Matthias-Ginter  -  Freiburg
# Max Rosenfelder  -  DF -  https://fbref.com/en/players/b6ceba6b/Max-Rosenfelder  -  Freiburg
# Eren Dinkçi  -  MF -  https://fbref.com/en/players/4ccd8957/Eren-Dinkci  -  Freiburg
# Merlin Röhl  -  MF -  https://fbref.com/en/players/1f2c7b55/Merlin-Rohl  -  Freiburg
# Florian Müller  -  GK -  https://fbref.com/en/players/cbac6ec9/Florian-Muller  -  Freiburg
# Lucas Höler  -  MF,FW -  https://fbref.com/en/players/ca618d23/Lucas-Holer  -  Freiburg
# Florent Muslija  -  FW,DF -  https://fbref.com/en/players/ae961785/Florent-Muslija  -  Freiburg
# Nicolas Höfler  -  MF -  https://fbref.com/en/players/5d8e331f/Nicolas-Hofler  -  Freiburg
# Noah Weißhaupt  -  FW -  https://fbref.com/en/players/dd676a97/Noah-Weisshaupt  -  Freiburg
# Roland Sallai  -  FW,MF -  https://fbref.com/en/players/bf075f6b/Roland-Sallai  -  Freiburg
# Jordy Makengo  -  DF -  https://fbref.com/en/players/14b09c41/Jordy-Makengo  -  Freiburg
# Ifechukwu Ogbus  -  DF -  https://fbref.com/en/players/d41472b7/Ifechukwu-Ogbus  -  Freiburg
# Michael Gregoritsch  -  FW -  https://fbref.com/en/players/8e235926/Michael-Gregoritsch  -  Freiburg
# Johan Manzambi  -  FW -  https://fbref.com/en/players/8fcf0e12/Johan-Manzambi  -  Freiburg
# Kiliann Sildillia  -  FW -  https://fbref.com/en/players/313254a3/Kiliann-Sildillia  -  Freiburg
# Jannik Huth  -  GK -  https://fbref.com/en/players/e8fd2e5b/Jannik-Huth  -  Freiburg
# Kenneth Schmidt  -  DF -  https://fbref.com/en/players/7d31f1cb/Kenneth-Schmidt  -  Freiburg
# Scraping players from Villarreal...
# Diego Conde  -  GK -  https://fbref.com/en/players/4eae5bc4/Diego-Conde  -  Villarreal
# Kiko Femenía  -  DF -  https://fbref.com/en/players/e5d01ecf/Kiko-Femenia  -  Villarreal
# Sergi Cardona  -  DF -  https://fbref.com/en/players/74e90475/Sergi-Cardona  -  Villarreal
# Santi Comesaña  -  MF -  https://fbref.com/en/players/5ae499d0/Santi-Comesana  -  Villarreal
# Daniel Parejo  -  MF -  https://fbref.com/en/players/7460ca0d/Daniel-Parejo  -  Villarreal
# Alex Baena  -  MF,FW -  https://fbref.com/en/players/518f2234/Alex-Baena  -  Villarreal
# Logan Costa  -  DF -  https://fbref.com/en/players/bfb2056e/Logan-Costa  -  Villarreal
# Raúl Albiol  -  DF -  https://fbref.com/en/players/4bd414c1/Raul-Albiol  -  Villarreal
# Thierno Barry  -  FW -  https://fbref.com/en/players/52c3244b/Thierno-Barry  -  Villarreal
# Eric Bailly  -  DF -  https://fbref.com/en/players/a1232f4e/Eric-Bailly  -  Villarreal
# Pape Gueye  -  MF -  https://fbref.com/en/players/7155e3e1/Pape-Gueye  -  Villarreal
# Ayoze Pérez  -  FW -  https://fbref.com/en/players/819aa8e7/Ayoze-Perez  -  Villarreal
# Ilias Akhomach  -  MF -  https://fbref.com/en/players/b8bd60fe/Ilias-Akhomach  -  Villarreal
# Nicolas Pépé  -  FW,MF -  https://fbref.com/en/players/57e3f0c7/Nicolas-Pepe  -  Villarreal
# Yeremi Pino  -  MF -  https://fbref.com/en/players/540ec57b/Yeremi-Pino  -  Villarreal
# Arnaut Danjuma  -  FW -  https://fbref.com/en/players/f08490a6/Arnaut-Danjuma  -  Villarreal
# Gerard Moreno  -  FW -  https://fbref.com/en/players/81f0781e/Gerard-Moreno  -  Villarreal
# Willy Kambwala  -  DF -  https://fbref.com/en/players/6a7353d7/Willy-Kambwala  -  Villarreal
# Denis Suárez  -  MF -  https://fbref.com/en/players/12c50af5/Denis-Suarez  -  Villarreal
# Ramón Terrats  -  MF -  https://fbref.com/en/players/f36016a5/Ramon-Terrats  -  Villarreal
# Juan Bernat  -  DF,MF -  https://fbref.com/en/players/433dc9a2/Juan-Bernat  -  Villarreal
# Pau Navarro  -  DF -  https://fbref.com/en/players/3171351c/Pau-Navarro  -  Villarreal
# Pau Cabanes  -  MF -  https://fbref.com/en/players/53440b64/Pau-Cabanes  -  Villarreal
# Iker Álvarez  -  GK -  https://fbref.com/en/players/13619663/Iker-Alvarez  -  Villarreal
# Antonio Espigare  -  DF -  https://fbref.com/en/players/d97cfe6f/Antonio-Espigare  -  Villarreal
# Karl Etta  -  FW -  https://fbref.com/en/players/f0f499ea/Karl-Etta  -  Villarreal
# Luiz Lúcio Reis Júnior  -  GK -  https://fbref.com/en/players/d0530e29/Luiz-Lucio-Reis-Junior  -  Villarreal
# Daniel Requena  -  MF -  https://fbref.com/en/players/34d29ab9/Daniel-Requena  -  Villarreal
# Arnau Solà  -  DF -  https://fbref.com/en/players/c8c8ce16/Arnau-Sola  -  Villarreal
# Scraping players from Lille...
# Lucas Chevalier  -  GK -  https://fbref.com/en/players/b3d76d84/Lucas-Chevalier  -  Lille
# Bafodé Diakité  -  DF -  https://fbref.com/en/players/1bfb6fef/Bafode-Diakite  -  Lille
# Alexsandro Ribeiro  -  DF -  https://fbref.com/en/players/102c9665/Alexsandro-Ribeiro  -  Lille
# Benjamin André  -  MF -  https://fbref.com/en/players/ef9c1c95/Benjamin-Andre  -  Lille
# Gabriel Gudmundsson  -  DF -  https://fbref.com/en/players/d5d22a58/Gabriel-Gudmundsson  -  Lille
# Edon Zhegrova  -  FW,MF -  https://fbref.com/en/players/34a88e3e/Edon-Zhegrova  -  Lille
# Angel Gomes  -  MF -  https://fbref.com/en/players/645a3363/Angel-Gomes  -  Lille
# Jonathan David  -  FW -  https://fbref.com/en/players/ce50fd99/Jonathan-David  -  Lille
# Osame Sahraoui  -  MF,FW -  https://fbref.com/en/players/6f9fa232/Osame-Sahraoui  -  Lille
# Tiago Santos  -  DF -  https://fbref.com/en/players/3eeebc87/Tiago-Santos  -  Lille
# Thomas Meunier  -  DF -  https://fbref.com/en/players/e162b013/Thomas-Meunier  -  Lille
# Aïssa Mandi  -  DF -  https://fbref.com/en/players/fbd6378b/Aissa-Mandi  -  Lille
# ...
# Jeffrey Schlupp  -  MF,DF -  https://fbref.com/en/players/3312f911/Jeffrey-Schlupp  -  Crystal Palace
# Jordan Ayew  -  FW,MF -  https://fbref.com/en/players/da052c14/Jordan-Ayew  -  Crystal Palace
# Asher Agbinone  -  MF -  https://fbref.com/en/players/6a10efb3/Asher-Agbinone  -  Crystal Palace
# Naouirou Ahamada  -  MF -  https://fbref.com/en/players/a6c58494/Naouirou-Ahamada  -  Crystal Palace
# Justin Devenny  -  MF -  https://fbref.com/en/players/6c2b66fc/Justin-Devenny  -  Crystal Palace
# Rob Holding  -  DF -  https://fbref.com/en/players/d79a8c87/Rob-Holding  -  Crystal Palace
# Sam Johnstone  -  GK -  https://fbref.com/en/players/9e5708be/Sam-Johnstone  -  Crystal Palace
# Caleb Kporha  -  DF -  https://fbref.com/en/players/c80f8c9d/Caleb-Kporha  -  Crystal Palace
# Remi Matthews  -  GK -  https://fbref.com/en/players/27f4f772/Remi-Matthews  -  Crystal Palace
# Kaden Rodney  -  DF -  https://fbref.com/en/players/49375cdd/Kaden-Rodney  -  Crystal Palace
# Matt Turner  -  GK -  https://fbref.com/en/players/4a51ba65/Matt-Turner  -  Crystal Palace
# Franco Umeh-Chibueze  -  MF -  https://fbref.com/en/players/8e526344/Franco-Umeh-Chibueze  -  Crystal Palace
# Joel Ward  -  DF,MF -  https://fbref.com/en/players/8a7ff278/Joel-Ward  -  Crystal Palace
# Scraping players from Angers...
# Yahia Fofana  -  GK -  https://fbref.com/en/players/9d420dad/Yahia-Fofana  -  Angers
# Jordan Lefort  -  DF -  https://fbref.com/en/players/c3e4ecbb/Jordan-Lefort  -  Angers
# Himad Abdelli  -  MF,FW -  https://fbref.com/en/players/7978cbf0/Himad-Abdelli  -  Angers
# Carlens Arcus  -  DF -  https://fbref.com/en/players/5e837126/Carlens-Arcus  -  Angers
# Jean-Eudes Aholou  -  MF -  https://fbref.com/en/players/48b28bfd/Jean-Eudes-Aholou  -  Angers
# Florent Hanin  -  DF -  https://fbref.com/en/players/6bfb4303/Florent-Hanin  -  Angers
# Farid El Melali  -  FW,DF -  https://fbref.com/en/players/d21e361a/Farid-El-Melali  -  Angers
# Emmanuel Biumla  -  DF -  https://fbref.com/en/players/e5a94f46/Emmanuel-Biumla  -  Angers
# Haris Belkebla  -  MF -  https://fbref.com/en/players/2b1bed19/Haris-Belkebla  -  Angers
# Yassin Belkhdim  -  MF -  https://fbref.com/en/players/e21d1928/Yassin-Belkhdim  -  Angers
# Sidiki Cherif  -  FW -  https://fbref.com/en/players/78430598/Sidiki-Cherif  -  Angers
# Cédric Hountondji  -  DF -  https://fbref.com/en/players/00891164/Cedric-Hountondji  -  Angers
# Abdoulaye Bamba  -  DF -  https://fbref.com/en/players/7fecbcdb/Abdoulaye-Bamba  -  Angers
# Jacques Ekomie  -  DF -  https://fbref.com/en/players/8d5016e6/Jacques-Ekomie  -  Angers
# Jim Allevinah  -  FW -  https://fbref.com/en/players/1956b948/Jim-Allevinah  -  Angers
# Bamba Dieng  -  FW -  https://fbref.com/en/players/40774c6b/Bamba-Dieng  -  Angers
# Zinedine Ferhat  -  FW,MF -  https://fbref.com/en/players/005c0807/Zinedine-Ferhat  -  Angers
# Pierrick Capelle  -  MF -  https://fbref.com/en/players/79b2399c/Pierrick-Capelle  -  Angers
# Esteban Lepaul  -  FW -  https://fbref.com/en/players/85ce1949/Esteban-Lepaul  -  Angers
# Ibrahima Niane  -  FW,MF -  https://fbref.com/en/players/46faabfa/Ibrahima-Niane  -  Angers
# Lilian Raolisoa  -  DF -  https://fbref.com/en/players/79a793b7/Lilian-Raolisoa  -  Angers
# Zinédine Ould Khaled  -  MF -  https://fbref.com/en/players/6b4436ba/Zinedine-Ould-Khaled  -  Angers
# Lois Diony  -  FW -  https://fbref.com/en/players/4be0b467/Lois-Diony  -  Angers
# Joseph Lopy  -  DF,MF -  https://fbref.com/en/players/3886c982/Joseph-Lopy  -  Angers
# Melvin Zinga  -  GK -  https://fbref.com/en/players/1d59fe9c/Melvin-Zinga  -  Angers
# Scraping players from Las Palmas...
# Alberto Moleiro  -  FW,MF -  https://fbref.com/en/players/c2c8897d/Alberto-Moleiro  -  Las Palmas
# Kirian Rodríguez  -  MF -  https://fbref.com/en/players/9b130479/Kirian-Rodriguez  -  Las Palmas
# Oliver McBurnie  -  FW -  https://fbref.com/en/players/78b8ac63/Oliver-McBurnie  -  Las Palmas
# Jasper Cillessen  -  GK -  https://fbref.com/en/players/04ac8285/Jasper-Cillessen  -  Las Palmas
# Javier Muñoz  -  MF -  https://fbref.com/en/players/ec7c84c2/Javier-Munoz  -  Las Palmas
# Álex Suárez  -  DF -  https://fbref.com/en/players/9c137b36/Alex-Suarez  -  Las Palmas
# Álex Muñoz  -  DF -  https://fbref.com/en/players/853f211e/Alex-Munoz  -  Las Palmas
# Mika Màrmol  -  DF -  https://fbref.com/en/players/e7630876/Mika-Marmol  -  Las Palmas
# Marvin  -  DF,FW -  https://fbref.com/en/players/efaefda0/Marvin  -  Las Palmas
# Sandro Ramírez  -  FW,MF -  https://fbref.com/en/players/833fb62e/Sandro-Ramirez  -  Las Palmas
# Scott McKenna  -  DF -  https://fbref.com/en/players/4e5a4cbc/Scott-McKenna  -  Las Palmas
# Juan Herzog  -  DF -  https://fbref.com/en/players/3a18abe2/Juan-Herzog  -  Las Palmas
# Fábio Silva  -  FW,MF -  https://fbref.com/en/players/e7aa9d7c/Fabio-Silva  -  Las Palmas
# Dario Essugo  -  MF -  https://fbref.com/en/players/1e4319ac/Dario-Essugo  -  Las Palmas
# Viti  -  DF -  https://fbref.com/en/players/c56a2d27/Viti  -  Las Palmas
# José Campaña  -  MF -  https://fbref.com/en/players/61220da2/Jose-Campana  -  Las Palmas
# Enzo Loiodice  -  MF -  https://fbref.com/en/players/6bca20fe/Enzo-Loiodice  -  Las Palmas
# Jaime Mata  -  FW -  https://fbref.com/en/players/02319ad7/Jaime-Mata  -  Las Palmas
# Adnan Januzaj  -  MF,FW -  https://fbref.com/en/players/4737cebe/Adnan-Januzaj  -  Las Palmas
# Dinko Horkaš  -  GK -  https://fbref.com/en/players/8fafc04d/Dinko-Horkas  -  Las Palmas
# Benito Ramírez  -  DF,MF -  https://fbref.com/en/players/db714daf/Benito-Ramirez  -  Las Palmas
# Manuel Fuster  -  MF,FW -  https://fbref.com/en/players/618f396a/Manuel-Fuster  -  Las Palmas
# Daley Sinkgraven  -  DF -  https://fbref.com/en/players/73000a79/Daley-Sinkgraven  -  Las Palmas
# Fabio González  -  MF -  https://fbref.com/en/players/5418d47c/Fabio-Gonzalez  -  Las Palmas
# Marc Cardona  -  FW -  https://fbref.com/en/players/b92b456a/Marc-Cardona  -  Las Palmas
# Pejiño  -  FW -  https://fbref.com/en/players/8c4e56cb/Pejino  -  Las Palmas
# Aboubacar Bassinga  -  MF -  https://fbref.com/en/players/22a312ec/Aboubacar-Bassinga  -  Las Palmas
# Iván Gil  -  MF -  https://fbref.com/en/players/1fa0e5fa/Ivan-Gil  -  Las Palmas
# Álvaro Killane  -  GK -  https://fbref.com/en/players/8194b09d/Alvaro-Killane  -  Las Palmas
# Valentín Pezzolesi  -  DF -  https://fbref.com/en/players/06d00fbd/Valentin-Pezzolesi  -  Las Palmas
# Víctor Puig  -  GK -  https://fbref.com/en/players/9f0d158b/Victor-Puig  -  Las Palmas
# Scraping players from Holstein Kiel...
# Timo Becker  -  DF -  https://fbref.com/en/players/543ddcaf/Timo-Becker  -  Holstein Kiel
# Timon Weiner  -  GK -  https://fbref.com/en/players/1fb2d1b0/Timon-Weiner  -  Holstein Kiel
# Magnus Knudsen  -  MF -  https://fbref.com/en/players/a48fb0c7/Magnus-Knudsen  -  Holstein Kiel
# Lewis Holtby  -  MF -  https://fbref.com/en/players/410ab123/Lewis-Holtby  -  Holstein Kiel
# Benedikt Pichler  -  FW -  https://fbref.com/en/players/c184c8c8/Benedikt-Pichler  -  Holstein Kiel
# Finn Porath  -  DF,MF -  https://fbref.com/en/players/b020d807/Finn-Porath  -  Holstein Kiel
# Shuto Machino  -  FW,MF -  https://fbref.com/en/players/964dde35/Shuto-Machino  -  Holstein Kiel
# Carl Johansson  -  DF -  https://fbref.com/en/players/02f7a79a/Carl-Johansson  -  Holstein Kiel
# Patrick Erras  -  DF -  https://fbref.com/en/players/e3f6253d/Patrick-Erras  -  Holstein Kiel
# Max Geschwill  -  DF -  https://fbref.com/en/players/0ffda76d/Max-Geschwill  -  Holstein Kiel
# Armin Gigovic  -  MF -  https://fbref.com/en/players/d0a0858e/Armin-Gigovic  -  Holstein Kiel
# Marko Ivezić  -  DF -  https://fbref.com/en/players/964f4f30/Marko-Ivezic  -  Holstein Kiel
# Alexander Bernhardsson  -  DF,FW -  https://fbref.com/en/players/dea1d183/Alexander-Bernhardsson  -  Holstein Kiel
# Tymoteusz Puchacz  -  DF -  https://fbref.com/en/players/c68b1b13/Tymoteusz-Puchacz  -  Holstein Kiel
# Marco Komenda  -  DF -  https://fbref.com/en/players/e7efcdb8/Marco-Komenda  -  Holstein Kiel
# Nicolai Remberg  -  MF -  https://fbref.com/en/players/625fd441/Nicolai-Remberg  -  Holstein Kiel
# Lasse Rosenboom  -  DF -  https://fbref.com/en/players/1df23153/Lasse-Rosenboom  -  Holstein Kiel
# Andu Kelati  -  MF -  https://fbref.com/en/players/58391f96/Andu-Kelati  -  Holstein Kiel
# Steven Skrzybski  -  MF,FW -  https://fbref.com/en/players/58ce23e5/Steven-Skrzybski  -  Holstein Kiel
# Dominik Javorček  -  DF -  https://fbref.com/en/players/3a2cf67d/Dominik-Javorcek  -  Holstein Kiel
# Jann-Fiete Arp  -  FW,MF -  https://fbref.com/en/players/c21fb312/Jann-Fiete-Arp  -  Holstein Kiel
# Marvin Schulz  -  MF -  https://fbref.com/en/players/651167c8/Marvin-Schulz  -  Holstein Kiel
# Thomas Dähne  -  GK -  https://fbref.com/en/players/f194035d/Thomas-Dahne  -  Holstein Kiel
# Phil Harres  -  FW -  https://fbref.com/en/players/07db670d/Phil-Harres  -  Holstein Kiel
# Scraping players from Bochum...
# Patrick Drewes  -  GK -  https://fbref.com/en/players/a8403737/Patrick-Drewes  -  Bochum
# Felix Passlack  -  DF -  https://fbref.com/en/players/5c899683/Felix-Passlack  -  Bochum
# Maximilian Wittek  -  DF -  https://fbref.com/en/players/edb2712b/Maximilian-Wittek  -  Bochum
# Jakov Medić  -  DF -  https://fbref.com/en/players/5f5ebdae/Jakov-Medic  -  Bochum
# Ibrahima Sissoko  -  MF,DF -  https://fbref.com/en/players/0f8418aa/Ibrahima-Sissoko  -  Bochum
# Matúš Bero  -  MF -  https://fbref.com/en/players/b5e0af76/Matus-Bero  -  Bochum
# Dani de Wit  -  MF -  https://fbref.com/en/players/48a2b92a/Dani-de-Wit  -  Bochum
# Philipp Hofmann  -  FW -  https://fbref.com/en/players/877bc844/Philipp-Hofmann  -  Bochum
# Myron Boadu  -  FW -  https://fbref.com/en/players/5b479568/Myron-Boadu  -  Bochum
# Anthony Losilla  -  MF -  https://fbref.com/en/players/07c7eb0c/Anthony-Losilla  -  Bochum
# Erhan Mašović  -  DF -  https://fbref.com/en/players/a396fb61/Erhan-Masovic  -  Bochum
# Moritz Broschinski  -  FW -  https://fbref.com/en/players/bbd79358/Moritz-Broschinski  -  Bochum
# Lukas Daschner  -  MF,FW -  https://fbref.com/en/players/93a8c4f9/Lukas-Daschner  -  Bochum
# Tim Oermann  -  DF -  https://fbref.com/en/players/57ec75bf/Tim-Oermann  -  Bochum
# Ivan Ordets  -  DF -  https://fbref.com/en/players/86c75897/Ivan-Ordets  -  Bochum
# Koji Miyoshi  -  MF -  https://fbref.com/en/players/77bf714c/Koji-Miyoshi  -  Bochum
# Aliou Badara Baldé  -  MF,FW -  https://fbref.com/en/players/7362a6f2/Aliou-Badara-Balde  -  Bochum
# Moritz-Broni Kwarteng  -  MF -  https://fbref.com/en/players/1e2057aa/Moritz-Broni-Kwarteng  -  Bochum
# Mats Pannewig  -  MF -  https://fbref.com/en/players/2420dbac/Mats-Pannewig  -  Bochum
# Samuel Bamba  -  FW,MF -  https://fbref.com/en/players/489d4867/Samuel-Bamba  -  Bochum
# Agon Elezi  -  MF -  https://fbref.com/en/players/c5af2e95/Agon-Elezi  -  Bochum
# Cristian Gamboa  -  DF,MF -  https://fbref.com/en/players/f27680d9/Cristian-Gamboa  -  Bochum
# Timo Horn  -  GK -  https://fbref.com/en/players/3cd9e95a/Timo-Horn  -  Bochum
# Noah Loosli  -  DF -  https://fbref.com/en/players/5dbfd101/Noah-Loosli  -  Bochum
# Scraping players from Southampton...
# Flynn Downes  -  MF -  https://fbref.com/en/players/69fdb896/Flynn-Downes  -  Southampton
# Jan Bednarek  -  DF -  https://fbref.com/en/players/4115ce4e/Jan-Bednarek  -  Southampton
# Yukinari Sugawara  -  DF -  https://fbref.com/en/players/580bcd18/Yukinari-Sugawara  -  Southampton
# Taylor Harwood-Bellis  -  DF -  https://fbref.com/en/players/47327321/Taylor-Harwood-Bellis  -  Southampton
# Aaron Ramsdale  -  GK -  https://fbref.com/en/players/466fb2c5/Aaron-Ramsdale  -  Southampton
# Kyle Walker-Peters  -  DF -  https://fbref.com/en/players/984a5a64/Kyle-Walker-Peters  -  Southampton
# Ben Brereton  -  FW -  https://fbref.com/en/players/57827369/Ben-Brereton  -  Southampton
# Tyler Dibling  -  FW,MF -  https://fbref.com/en/players/bdcc89ae/Tyler-Dibling  -  Southampton
# Mateus Fernandes  -  MF -  https://fbref.com/en/players/ef491564/Mateus-Fernandes  -  Southampton
# Joe Aribo  -  MF -  https://fbref.com/en/players/328f7d51/Joe-Aribo  -  Southampton
# Jack Stephens  -  DF -  https://fbref.com/en/players/6adbc307/Jack-Stephens  -  Southampton
# Adam Armstrong  -  FW -  https://fbref.com/en/players/68c720b5/Adam-Armstrong  -  Southampton
# William Smallbone  -  MF -  https://fbref.com/en/players/5e105217/William-Smallbone  -  Southampton
# Cameron Archer  -  FW -  https://fbref.com/en/players/05e8ca6d/Cameron-Archer  -  Southampton
# Charlie Taylor  -  DF -  https://fbref.com/en/players/cc2d7ad5/Charlie-Taylor  -  Southampton
# Alex McCarthy  -  GK -  https://fbref.com/en/players/36c2ca73/Alex-McCarthy  -  Southampton
# Lesley Ugochukwu  -  MF -  https://fbref.com/en/players/1df4a109/Lesley-Ugochukwu  -  Southampton
# Ryan Fraser  -  FW -  https://fbref.com/en/players/d56543a0/Ryan-Fraser  -  Southampton
# Ross Stewart  -  FW,MF -  https://fbref.com/en/players/18986367/Ross-Stewart  -  Southampton
# Adam Lallana  -  MF -  https://fbref.com/en/players/99813635/Adam-Lallana  -  Southampton
# Ryan Manning  -  DF -  https://fbref.com/en/players/847b53eb/Ryan-Manning  -  Southampton
# Maxwel Cornet  -  FW -  https://fbref.com/en/players/beb391dd/Maxwel-Cornet  -  Southampton
# Samuel Edozie  -  DF,FW -  https://fbref.com/en/players/007414dd/Samuel-Edozie  -  Southampton
# Paul Onuachu  -  FW -  https://fbref.com/en/players/c06d1086/Paul-Onuachu  -  Southampton
# Carlos Alcaraz  -  MF -  https://fbref.com/en/players/4abac767/Carlos-Alcaraz  -  Southampton
# Samuel Amo-Ameyaw  -  DF -  https://fbref.com/en/players/9eedf0e0/Samuel-Amo-Ameyaw  -  Southampton
# James Bree  -  DF,MF -  https://fbref.com/en/players/c07b7c5c/James-Bree  -  Southampton
# Joe Lumley  -  GK -  https://fbref.com/en/players/bdf3a08e/Joe-Lumley  -  Southampton
# Nathan Wood-Gordon  -  DF -  https://fbref.com/en/players/4ccf2d5b/Nathan-Wood-Gordon  -  Southampton
# Scraping players from Wolves...
# Mario Lemina  -  MF,FW -  https://fbref.com/en/players/2b471f99/Mario-Lemina  -  Wolves
# João Gomes  -  MF -  https://fbref.com/en/players/8b57ad2c/Joao-Gomes  -  Wolves
# Jørgen Strand Larsen  -  FW -  https://fbref.com/en/players/f553b2b3/Jorgen-Strand-Larsen  -  Wolves
# Rayan Aït-Nouri  -  DF,MF -  https://fbref.com/en/players/9b398aea/Rayan-Ait-Nouri  -  Wolves
# Matheus Cunha  -  MF,FW -  https://fbref.com/en/players/dc62b55d/Matheus-Cunha  -  Wolves
# Jean-Ricner Bellegarde  -  MF,FW -  https://fbref.com/en/players/10f0fdd3/Jean-Ricner-Bellegarde  -  Wolves
# Toti Gomes  -  DF -  https://fbref.com/en/players/f0caab96/Toti-Gomes  -  Wolves
# Sam Johnstone  -  GK -  https://fbref.com/en/players/9e5708be/Sam-Johnstone  -  Wolves
# Yerson Mosquera  -  DF -  https://fbref.com/en/players/1e159d70/Yerson-Mosquera  -  Wolves
# Nélson Semedo  -  DF -  https://fbref.com/en/players/d04b94db/Nelson-Semedo  -  Wolves
# Craig Dawson  -  DF -  https://fbref.com/en/players/3e9e06cb/Craig-Dawson  -  Wolves
# André  -  MF -  https://fbref.com/en/players/ec604e2c/Andre  -  Wolves
# Hwang Hee-chan  -  FW,MF -  https://fbref.com/en/players/169fd162/Hwang-Hee-chan  -  Wolves
# Matt Doherty  -  DF -  https://fbref.com/en/players/d557d734/Matt-Doherty  -  Wolves
# José Sá  -  GK -  https://fbref.com/en/players/903b6e8b/Jose-Sa  -  Wolves
# Rodrigo Gomes  -  FW,MF -  https://fbref.com/en/players/8dcf77c0/Rodrigo-Gomes  -  Wolves
# Carlos Forbs  -  MF -  https://fbref.com/en/players/8a310070/Carlos-Forbs  -  Wolves
# Santiago Bueno  -  DF -  https://fbref.com/en/players/edc98fac/Santiago-Bueno  -  Wolves
# Gonçalo Guedes  -  MF,FW -  https://fbref.com/en/players/e6bc67d7/Goncalo-Guedes  -  Wolves
# Tommy Doyle  -  MF -  https://fbref.com/en/players/5526deb1/Tommy-Doyle  -  Wolves
# Daniel Podence  -  MF,FW -  https://fbref.com/en/players/7fcc71d8/Daniel-Podence  -  Wolves
# Pablo Sarabia  -  FW,MF -  https://fbref.com/en/players/9744ff80/Pablo-Sarabia  -  Wolves
# Chiquinho  -  MF -  https://fbref.com/en/players/dc6c2f02/Chiquinho  -  Wolves
# Daniel Bentley  -  GK -  https://fbref.com/en/players/68db6358/Daniel-Bentley  -  Wolves
# Alfie Pond  -  DF -  https://fbref.com/en/players/039c3d96/Alfie-Pond  -  Wolves
# Boubacar Traoré  -  MF -  https://fbref.com/en/players/999ceb5f/Boubacar-Traore  -  Wolves
# Players data saved to ../../data/players_data.csv

# %% [markdown]
# ### Récuparation des scouting report de tous les joueurs

# %%
class DataPlayerExtractor:
    def __init__(self, players_data_path, output_csv_path='../data/scouting_report_v2.csv'):
        self.players_data_path = players_data_path
        self.output_csv_path = output_csv_path
        self.soup = None
        self.players_df = None

    def fetch_data(self, url):
        """Fetch the content of the webpage."""
        try:
            response = requests.get(url)
            response.raise_for_status()
            self.soup = BeautifulSoup(response.text, 'html.parser')
        except requests.exceptions.HTTPError as http_err:
            print(f"HTTP error occurred: {http_err}")
        except Exception as err:
            print(f"Other error occurred: {err}")
    
    def extract_player_name(self):
        """Extract the player name from the webpage."""
        if self.soup:
            player_name_tag = self.soup.find('h1')
            return player_name_tag.text.strip() if player_name_tag else "Nom non trouvé"
        return None

    def extract_scouting_report(self):
        """Extract the scouting report (if any) from the webpage."""
        if self.soup:
            table = self.soup.find('table')
            if not table:
                print("Table introuvable.")
                return None, None
            
            headers = []
            rows_data = []
            
            # Extraction des en-têtes de tableau
            thead = table.find('thead')
            if thead:
                headers = [th.text.strip() for th in thead.find_all('th')]

            # Extraction des lignes du tableau
            tbody = table.find('tbody')
            if tbody:
                for row in tbody.find_all('tr'):
                    row_data = []
                    for cell in row.find_all(['th', 'td']):
                        row_data.append(cell.text.strip())
                    
                    # Ignorer les lignes vides
                    if any(row_data):
                        rows_data.append(row_data)
            
            return headers, rows_data
        return None, None

    def save_to_csv(self, player_name, rows_data):
        """Save player data to a CSV file."""
        # Colonnes à utiliser dans le CSV
        columns = ['player_name'] + [row[0] for row in rows_data]

        # Extraire uniquement les valeurs (sans le nom des statistiques)
        values = [player_name] + [row[1] for row in rows_data]

        # Vérifier si le fichier CSV existe déjà
        file_exists = os.path.isfile(self.output_csv_path)

        # Créer le répertoire 'data' si nécessaire
        os.makedirs(os.path.dirname(self.output_csv_path), exist_ok=True)

        # Ajouter les données au CSV
        with open(self.output_csv_path, 'a', newline='', encoding='utf-8') as f:
            writer = csv.writer(f)
            if not file_exists:
                # Écrire les en-têtes si le fichier est créé pour la première fois
                writer.writerow(columns)
            # Écrire les données du joueur
            writer.writerow(values)
        
        print(f"Données sauvegardées dans {self.output_csv_path}")

    def process_players(self):
        """Process all players listed in the input CSV."""
        # Charger le fichier players_data.csv
        self.players_df = pd.read_csv(self.players_data_path)

        # Initialiser le fichier de sortie scouting_report.csv s'il n'existe pas
        if not os.path.isfile(self.output_csv_path):
            with open(self.output_csv_path, 'w', newline='', encoding='utf-8') as f:
                writer = csv.writer(f)
                writer.writerow(['Player Name', 'Stat Name 1', 'Stat Value 1', 'Stat Name 2', 'Stat Value 2', '...'])

        # Boucle sur chaque joueur et extraction des données
        for index, row in self.players_df.iterrows():
            player_name = row['Player Name']
            player_url = row['Player URL']
            print(f"Processing {player_name} ({player_url})")

            self.fetch_data(player_url)
            headers, scouting_data = self.extract_scouting_report()
            
            if scouting_data:
                self.save_to_csv(player_name, scouting_data)
            else:
                print(f"No scouting report found for {player_name}.")
            
            # Attendre 12 secondes avant de traiter le prochain joueur
            time.sleep(12)

# %%
# Utilisation de la classe pour scraper les données des joueurs et les enregistrer dans un fichier CSV
players_data_path = '../../data/players_data.csv'  # Chemin vers le fichier des joueurs
output_csv_path = '../../data/scouting_report_v2.csv'  # Chemin vers le fichier CSV de sortie

extractor = DataPlayerExtractor(players_data_path, output_csv_path)
extractor.process_players()
# Out:
# Processing Philipp Köhn (https://fbref.com/en/players/ff74841d/Philipp-Kohn)
# Données sauvegardées dans ../../data/scouting_report_v2.csv
# Processing Denis Zakaria (https://fbref.com/en/players/384d58d9/Denis-Zakaria)
# Données sauvegardées dans ../../data/scouting_report_v2.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 6
#       3 output_csv_path = '../../data/scouting_report_v2.csv'  # Chemin vers le fichier CSV de sortie
#       5 extractor = DataPlayerExtractor(players_data_path, output_csv_path)
# ----> 6 extractor.process_players()
#
# Cell In[4], line 118, in DataPlayerExtractor.process_players(self)
#     115     print(f"No scouting report found for {player_name}.")
#     117 # Attendre 12 secondes avant de traiter le prochain joueur
# --> 118 time.sleep(12)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Nettoyage des données

# %%
class ScoutingReportCleaner:
    def __init__(self, file_path, players_data_path):
        """Initialise la classe avec le chemin du fichier CSV et le fichier des joueurs."""
        self.file_path = file_path
        self.players_data_path = players_data_path
    
    def clean_and_save_data(self, output_path):
        """Charge, nettoie les données, ajoute la position des joueurs et sauvegarde les résultats dans un fichier CSV."""
        # Charger le fichier CSV du scouting report dans un DataFrame
        data = pd.read_csv(self.file_path)
        
        # Charger le fichier players_data.csv contenant le nom et la position des joueurs
        players_data = pd.read_csv(self.players_data_path)
        
        # Supprimer les doublons dans players_data basés sur 'Player Name' pour garder seulement la première occurrence
        players_data.drop_duplicates(subset=['Player Name'], inplace=True)
        
        # Renommer la colonne "Player Name" pour correspondre à "player_name" dans le rapport de scouting
        players_data.rename(columns={'Player Name': 'player_name'}, inplace=True)
        
        # Fonction interne pour vérifier si une valeur est un nombre valide ou un pourcentage
        def is_valid_value(val):
            # Vérifier si c'est un nombre avec ou sans pourcentage (ex: "86.3%", "-2.8")
            return bool(re.match(r'^-?\d+(\.\d+)?%?$', str(val)))
        
        # Fonction interne pour vérifier si une ligne est valide (chaque colonne après le nom doit être un nombre ou un pourcentage)
        def row_is_valid(row):
            return all(is_valid_value(val) for val in row[1:])
        
        # Nettoyer les données en conservant uniquement les lignes valides
        cleaned_data = data[data.apply(row_is_valid, axis=1)]
        
        # Fusionner sur la colonne "player_name" pour ajouter la colonne Position
        merged_data = pd.merge(cleaned_data, players_data[['player_name', 'Position']], on='player_name', how='left')
        
        # Supprimer les doublons sur toutes les colonnes
        merged_data.drop_duplicates(inplace=True)
        
        # Réorganiser les colonnes pour placer "Position" juste après "player_name"
        columns = ['player_name', 'Position'] + [col for col in cleaned_data.columns if col != 'player_name']
        final_data = merged_data[columns]
        
        # Sauvegarder les données nettoyées et enrichies dans un nouveau fichier CSV
        final_data.to_csv(output_path, index=False, header=True)
        
        print(f"Données nettoyées et enrichies sauvegardées dans {output_path}.")
        return final_data

# %%
# Utilisation de la classe
file_path = '../data/scouting_report.csv'  # Remplacez par votre chemin de fichier
players_data_path = '../data/players_data.csv'  # Chemin vers le fichier players_data.csv
output_path = '../data/cleaned_scouting_report.csv'  # Chemin de sortie pour les données nettoyées

# Créer une instance de la classe et nettoyer + enrichir les données
cleaner = ScoutingReportCleaner(file_path, players_data_path)

# Nettoyer et sauvegarder les données nettoyées
cleaned_data = cleaner.clean_and_save_data(output_path)

# Afficher un aperçu des données nettoyées
print("Aperçu des données nettoyées et enrichies :")
print(cleaned_data.head())
# Out:
# Données nettoyées et enrichies sauvegardées dans ../data/cleaned_scouting_report.csv.
# Aperçu des données nettoyées et enrichies :
#           player_name Position Buts (sans les pénaltys)  \
# 0       Denis Zakaria       MF                     0.22
# 1  Eliesse Ben Seghir    MF,FW                     0.37
# 2           Vanderson       DF                     0.16
# 3        Thilo Kehrer       DF                     0.13
# 4     Takumi Minamino       MF                     0.29
#
#   npxG: xG sans les pénaltys Total des tirs Passes décisives  \
# 0                       0.10           1.11             0.04
# 1                       0.17           3.22             0.28
# 2                       0.08           1.24             0.16
# 3                       0.05           0.74             0.04
# 4                       0.28           2.45             0.16
#
#   xAG: Prévu(s) Buts assistés npxG + xAG Actions menant à un tir  \
# 0                        0.05       0.15                    1.67
# 1                        0.25       0.41                    4.41
# 2                        0.12       0.19                    1.78
# 3                        0.05       0.10                    1.49
# 4                        0.23       0.52                    3.22
#
#   Passes tentées  ... Passes progressives Possessions progressives  \
# 0          49.84  ...                4.75                     1.04
# 1          46.42  ...                5.79                     5.88
# 2          56.94  ...                4.15                     1.56
# 3          63.90  ...                5.90                     0.83
# 4          35.07  ...                4.16                     1.79
#
#   Dribbles réussis  Touches (SurfRépOff)  Passes progressives reçues  Tacles  \
# 0             1.26                  1.00                        1.08    1.71
# 1             1.56                  4.32                       10.02    2.39
# 2             0.75                  2.10                        6.63    3.61
# 3             0.13                  1.14                        0.96    2.23
# 4             0.65                  4.77                        7.87    1.14
#
#    Interceptions  Balles contrées  Dégagements  Duel aérien gagnés
# 0           1.78             1.48         2.04                0.52
# 1           0.18             1.20         0.28                0.64
# 2           2.10             1.56         2.48                1.02
# 3           1.62             0.87         3.93                1.66
# 4           0.53             1.22         0.41                0.41
#
# [5 rows x 21 columns]
